# %%
import pandas as pd
import numpy as np

# %%
df_bw2017_zbwk = pd.read_csv("./data/bw2017zweitbundestagswahlkreise.csv",sep=';',encoding='latin_1')
df_bw2017_zbwk
# Out:
#    Wahlkreisnummer            Wahlkreisname  \
# 0            182.0  Bundestagswahlkreis 182
# 1            183.0  Bundestagswahlkreis 183
# 2              NaN          Stadt insgesamt
#
#    Wahlberechtigte ohne Sperrvermerk Anteil Wahlberechtigte ohne Sperrvermerk  \
# 0                             154856                                     77,5
# 1                             167595                                     74,8
# 2                             322451                                     76,1
#
#    Wahlberechtigte mit Sperrvermerk Anteil Wahlberechtigte mit Sperrvermerk  \
# 0                             44919                                    22,5
# 1                             56347                                    25,2
# 2                            101266                                    23,9
#
#    Wahlberechtigte insgesamt  Anteil Wahlberechtigte insgesamt  Wähler  \
# 0                     199775                               100  144841
# 1                     223942                               100  172393
# 2                     423717                               100  317234
#
#   Anteil Wähler  ...  DKP Anteil DKP   DM Anteil DM  ÖDP  Anteil ÖDP  \
# 0          72,5  ...   53          0  325       0,2  266         0,2
# 1            77  ...   91        0,1  250       0,1  295         0,2
# 2          74,9  ...  144          0  575       0,2  561         0,2
#
#    Tierschutzpartei Anteil Tierschutzpartei  V-Partei³ Anteil V-Partei³
# 0              1399                       1        252              0,2
# 1              1577                     0,9        364              0,2
# 2              2976                     0,9        616              0,2
#
# [3 rows x 52 columns]

# %%
df_bw2017_zst = pd.read_csv("./data/bw2017zweitstadtteile.csv",sep=';',encoding='latin_1')
df_bw2017_zst
# Out:
#     Stadtteilnummer             Stadtteilname  \
# 0               1.0                  Altstadt
# 1               2.0                Innenstadt
# 2               4.0               Westend-Süd
# 3               5.0              Westend-Nord
# 4               6.0              Nordend-West
# 5               7.0               Nordend-Ost
# 6               8.0                    Ostend
# 7               9.0                  Bornheim
# 8              10.0  Gutleut-/Bahnhofsviertel
# 9              11.0                    Gallus
# 10             12.0                Bockenheim
# 11             13.0        Sachsenhausen-Nord
# 12             14.0         Sachsenhausen-Süd
# 13             16.0                   Oberrad
# 14             17.0                 Niederrad
# 15             18.0                Schwanheim
# 16             19.0                 Griesheim
# 17             20.0                 Rödelheim
# 18             21.0                    Hausen
# 19             22.0                 Praunheim
# 20             24.0               Heddernheim
# 21             25.0               Niederursel
# 22             26.0                  Ginnheim
# 23             27.0                 Dornbusch
# 24             28.0               Eschersheim
# 25             29.0                 Eckenheim
# 26             30.0              Preungesheim
# 27             31.0                   Bonames
# 28             32.0               Berkersheim
# 29             33.0                Riederwald
# 30             34.0                  Seckbach
# 31             35.0                Fechenheim
# 32             36.0                    Höchst
# 33             37.0                      Nied
# 34             38.0                Sindlingen
# 35             39.0                 Zeilsheim
# 36             40.0           Unterliederbach
# 37             41.0                Sossenheim
# 38             42.0          Nieder-Erlenbach
# 39             43.0          Kalbach-Riedberg
# 40             44.0                   Harheim
# 41             45.0           Nieder-Eschbach
# 42             46.0            Bergen-Enkheim
# 43             47.0          Frankfurter Berg
# 44              NaN           Stadt insgesamt
#
#     Wahlberechtigte ohne Sperrvermerk  \
# 0                                1627
# 1                                2263
# 2                                7139
# 3                                4064
# 4                               13527
# 5                               10751
# 6                               12545
# 7                               14539
# 8                                3593
# 9                               13638
# 10                              16400
# 11                              13834
# 12                              12237
# 13                               5890
# 14                              10163
# 15                              10160
# 16                               9241
# 17                               7961
# 18                               3100
# 19                               7715
# 20                               8352
# 21                               7489
# 22                               7776
# 23                               8898
# 24                               7378
# 25                               6659
# 26                               6777
# 27                               3126
# 28                               1776
# 29                               2347
# 30                               4698
# 31                               6369
# 32                               5821
# 33                               8117
# 34                               4223
# 35                               5748
# 36                               7379
# 37                               6934
# 38                               2444
# 39                               8568
# 40                               2510
# 41                               5815
# 42                               9069
# 43                               3791
# 44                             322451
#
#    Anteil Wahlberechtigte ohne Sperrvermerk  Wahlberechtigte mit Sperrvermerk  \
# 0                                      73,2                               595
# 1                                      71,6                               899
# 2                                      62,8                              4227
# 3                                      69,3                              1804
# 4                                      67,3                              6562
# 5                                      70,2                              4564
# 6                                      72,1                              4845
# 7                                      74,5                              4968
# 8                                        73                              1328
# 9                                      75,3                              4475
# 10                                     72,3                              6286
# 11                                     68,8                              6267
# 12                                     68,2                              5695
# 13                                     78,5                              1609
# 14                                     76,4                              3140
# 15                                     82,1                              2214
# 16                                     85,1                              1621
# 17                                     78,8                              2142
# 18                                     78,3                               859
# 19                                     79,6                              1982
# 20                                     80,4                              2039
# 21                                     81,7                              1680
# 22                                     79,2                              2048
# 23                                     73,9                              3135
# 24                                     74,2                              2560
# 25                                     80,9                              1577
# 26                                     80,6                              1634
# 27                                     82,5                               663
# 28                                     76,3                               552
# 29                                       85                               413
# 30                                     77,8                              1337
# 31                                     83,3                              1278
# 32                                     82,3                              1253
# 33                                     83,2                              1640
# 34                                     85,6                               708
# 35                                     84,7                              1042
# 36                                     84,9                              1315
# 37                                     84,4                              1281
# 38                                       75                               813
# 39                                     78,3                              2378
# 40                                     76,5                               769
# 41                                     81,7                              1303
# 42                                     75,9                              2876
# 43                                       81                               890
# 44                                     76,1                            101266
#
#    Anteil Wahlberechtigte mit Sperrvermerk  Wahlberechtigte insgesamt  \
# 0                                     26,8                       2222
# 1                                     28,4                       3162
# 2                                     37,2                      11366
# 3                                     30,7                       5868
# 4                                     32,7                      20089
# 5                                     29,8                      15315
# 6                                     27,9                      17390
# 7                                     25,5                      19507
# 8                                       27                       4921
# 9                                     24,7                      18113
# 10                                    27,7                      22686
# 11                                    31,2                      20101
# 12                                    31,8                      17932
# 13                                    21,5                       7499
# 14                                    23,6                      13303
# 15                                    17,9                      12374
# 16                                    14,9                      10862
# 17                                    21,2                      10103
# 18                                    21,7                       3959
# 19                                    20,4                       9697
# 20                                    19,6                      10391
# 21                                    18,3                       9169
# 22                                    20,8                       9824
# 23                                    26,1                      12033
# 24                                    25,8                       9938
# 25                                    19,1                       8236
# 26                                    19,4                       8411
# 27                                    17,5                       3789
# 28                                    23,7                       2328
# 29                                      15                       2760
# 30                                    22,2                       6035
# 31                                    16,7                       7647
# 32                                    17,7                       7074
# 33                                    16,8                       9757
# 34                                    14,4                       4931
# 35                                    15,3                       6790
# 36                                    15,1                       8694
# 37                                    15,6                       8215
# 38                                      25                       3257
# 39                                    21,7                      10946
# 40                                    23,5                       3279
# 41                                    18,3                       7118
# 42                                    24,1                      11945
# 43                                      19                       4681
# 44                                    23,9                     423717
#
#     Anteil Wahlberechtigte insgesamt  Wähler Anteil Wähler  ...  DKP  \
# 0                                100    1662          74,8  ...    0
# 1                                100    2136          67,6  ...    0
# 2                                100    9636          84,8  ...    1
# 3                                100    4615          78,6  ...    3
# 4                                100   17068            85  ...    9
# 5                                100   12684          82,8  ...    6
# 6                                100   13544          77,9  ...    7
# 7                                100   15242          78,1  ...   13
# 8                                100    3648          74,1  ...    0
# 9                                100   12471          68,9  ...    5
# 10                               100   17510          77,2  ...    9
# 11                               100   16320          81,2  ...    6
# 12                               100   14127          78,8  ...    4
# 13                               100    5367          71,6  ...    2
# 14                               100    9416          70,8  ...    8
# 15                               100    8618          69,6  ...    5
# 16                               100    6662          61,3  ...    0
# 17                               100    7392          73,2  ...    5
# 18                               100    3142          79,4  ...    0
# 19                               100    7088          73,1  ...    1
# 20                               100    7509          72,3  ...    1
# 21                               100    6379          69,6  ...    3
# 22                               100    7113          72,4  ...    3
# 23                               100    9633          80,1  ...    4
# 24                               100    7772          78,2  ...    5
# 25                               100    5780          70,2  ...    7
# 26                               100    6315          75,1  ...    5
# 27                               100    2538            67  ...    3
# 28                               100    1811          77,8  ...    0
# 29                               100    1871          67,8  ...    3
# 30                               100    4542          75,3  ...    3
# 31                               100    4682          61,2  ...    3
# 32                               100    4702          66,5  ...    3
# 33                               100    6703          68,7  ...    3
# 34                               100    3284          66,6  ...    2
# 35                               100    4561          67,2  ...    1
# 36                               100    6027          69,3  ...    4
# 37                               100    5196          63,3  ...    0
# 38                               100    2759          84,7  ...    1
# 39                               100    9019          82,4  ...    2
# 40                               100    2758          84,1  ...    2
# 41                               100    5081          71,4  ...    1
# 42                               100    9428          78,9  ...    0
# 43                               100    3423          73,1  ...    1
# 44                               100  317234          74,9  ...  144
#
#    Anteil DKP   DM Anteil DM  ÖDP  Anteil ÖDP  Tierschutzpartei  \
# 0           0    4       0,2    5         0,3                13
# 1           0    9       0,4    4         0,2                14
# 2           0   10       0,1   15         0,2                36
# 3         0,1    7       0,2    6         0,1                17
# 4         0,1   13       0,1   31         0,2                95
# 5           0    6         0   22         0,2                88
# 6         0,1   21       0,2   24         0,2               105
# 7         0,1   19       0,1   30         0,2               148
# 8           0    4       0,1   11         0,3                20
# 9           0   34       0,3   21         0,2                98
# 10        0,1   20       0,1   45         0,3               122
# 11          0   22       0,1   30         0,2                73
# 12          0   15       0,1   22         0,2               124
# 13          0   13       0,2    8         0,2                62
# 14        0,1   22       0,2   16         0,2                86
# 15        0,1   14       0,2   10         0,1               103
# 16          0   19       0,3    7         0,1                99
# 17        0,1   23       0,3   12         0,2                74
# 18          0    4       0,1    3         0,1                20
# 19          0   11       0,2   12         0,2                88
# 20          0   11       0,1   10         0,1                85
# 21          0    5       0,1   10         0,2                70
# 22          0   19       0,3   26         0,4                69
# 23          0   15       0,2   17         0,2                80
# 24        0,1   11       0,1   13         0,2                75
# 25        0,1   15       0,3   10         0,2                90
# 26        0,1    9       0,1   11         0,2                66
# 27        0,1    5       0,2    5         0,2                33
# 28          0    2       0,1    4         0,2                10
# 29        0,2    2       0,1    6         0,3                37
# 30        0,1   11       0,2    6         0,1                48
# 31        0,1   10       0,2    6         0,1                68
# 32        0,1   16       0,3   13         0,3                52
# 33          0   30       0,5   11         0,2                96
# 34        0,1   12       0,4    4         0,1                50
# 35          0   29       0,6    2           0                70
# 36        0,1   12       0,2    8         0,1                71
# 37          0   20       0,4   11         0,2                80
# 38          0    3       0,1    7         0,3                32
# 39          0   12       0,1   21         0,2                90
# 40        0,1    6       0,2    2         0,1                37
# 41          0    7       0,1    8         0,2                52
# 42          0   17       0,2   14         0,1               102
# 43          0    6       0,2    2         0,1                28
# 44          0  575       0,2  561         0,2              2976
#
#    Anteil Tierschutzpartei  V-Partei³ Anteil V-Partei³
# 0                      0,8          4              0,2
# 1                      0,7          8              0,4
# 2                      0,4         16              0,2
# 3                      0,4          8              0,2
# 4                      0,6         38              0,2
# 5                      0,7         22              0,2
# 6                      0,8         22              0,2
# 7                        1         27              0,2
# 8                      0,6          7              0,2
# 9                      0,8         24              0,2
# 10                     0,7         43              0,2
# 11                     0,4         29              0,2
# 12                     0,9         26              0,2
# 13                     1,2         11              0,2
# 14                     0,9         23              0,2
# 15                     1,2         18              0,2
# 16                     1,5          8              0,1
# 17                       1         19              0,3
# 18                     0,6          2              0,1
# 19                     1,3         13              0,2
# 20                     1,1         10              0,1
# 21                     1,1         11              0,2
# 22                       1         11              0,2
# 23                     0,8         15              0,2
# 24                       1         14              0,2
# 25                     1,6         21              0,4
# 26                     1,1         21              0,3
# 27                     1,3         13              0,5
# 28                     0,6          4              0,2
# 29                       2          1              0,1
# 30                     1,1          5              0,1
# 31                     1,5          9              0,2
# 32                     1,1          5              0,1
# 33                     1,5         10              0,2
# 34                     1,6          6              0,2
# 35                     1,6          4              0,1
# 36                     1,2          6              0,1
# 37                     1,6          8              0,2
# 38                     1,2          4              0,1
# 39                       1         23              0,3
# 40                     1,4         12              0,4
# 41                       1         10              0,2
# 42                     1,1         16              0,2
# 43                     0,8          9              0,3
# 44                     0,9        616              0,2
#
# [45 rows x 52 columns]

# %%
df_bw2017_zwb = pd.read_csv("./data/bw2017zweitwahlbezirke.csv",sep=';',encoding='latin_1')
df_bw2017_zwb
# Out:
#      Wahlbezirksnummer                      Wahlbezirksname  \
# 0               1001.0  Stadthaus
# 1               1002.0  Stadthaus
# 2               4001.0  Liebfrauenschule
# 3               7001.0  Julius-Leber-Schule
# 4               8001.0  Ludwig-Börne-Schule
# ..                 ...                                  ...
# 486            94601.0  Briefwahl Bergen-Enkheim
# 487            94602.0  Briefwahl Bergen-Enkheim
# 488            94603.0  Briefwahl Bergen-Enkheim
# 489            94700.0  Briefwahl Frankfurter Berg
# 490                NaN                      Stadt insgesamt
#
#      Wahlberechtigte ohne Sperrvermerk  \
# 0                                  903
# 1                                  724
# 2                                  869
# 3                                  552
# 4                                  842
# ..                                 ...
# 486                                  0
# 487                                  0
# 488                                  0
# 489                                  0
# 490                             322451
#
#     Anteil Wahlberechtigte ohne Sperrvermerk  \
# 0                                       72,8
# 1                                       73,7
# 2                                       69,6
# 3                                       75,1
# 4                                       71,4
# ..                                       ...
# 486                                        0
# 487                                        0
# 488                                        0
# 489                                        0
# 490                                     76,1
#
#      Wahlberechtigte mit Sperrvermerk Anteil Wahlberechtigte mit Sperrvermerk  \
# 0                                 337                                    27,2
# 1                                 258                                    26,3
# 2                                 379                                    30,4
# 3                                 183                                    24,9
# 4                                 337                                    28,6
# ..                                ...                                     ...
# 486                                 0                                       0
# 487                                 0                                       0
# 488                                 0                                       0
# 489                                 0                                       0
# 490                            101266                                    23,9
#
#      Wahlberechtigte insgesamt  Anteil Wahlberechtigte insgesamt  Wähler  \
# 0                         1240                               100     643
# 1                          982                               100     455
# 2                         1248                               100     531
# 3                          735                               100     263
# 4                         1179                               100     493
# ..                         ...                               ...     ...
# 486                          0                                 0     886
# 487                          0                                 0     900
# 488                          0                                 0     921
# 489                          0                                 0     850
# 490                     423717                               100  317234
#
#     Anteil Wähler  ...  DKP Anteil DKP   DM Anteil DM  ÖDP  Anteil ÖDP  \
# 0            71,2  ...    0          0    1       0,2    3         0,5
# 1            62,8  ...    0          0    1       0,2    0           0
# 2            61,1  ...    0          0    3       0,6    3         0,6
# 3            47,6  ...    0          0    0         0    0           0
# 4            58,6  ...    0          0    5         1    1         0,2
# ..            ...  ...  ...        ...  ...       ...  ...         ...
# 486           100  ...    0          0    0         0    2         0,2
# 487           100  ...    0          0    2       0,2    1         0,1
# 488           100  ...    0          0    0         0    1         0,1
# 489           100  ...    0          0    1       0,1    0           0
# 490          74,9  ...  144          0  575       0,2  561         0,2
#
#      Tierschutzpartei Anteil Tierschutzpartei  V-Partei³ Anteil V-Partei³
# 0                   6                     0,9          3              0,5
# 1                   4                     0,9          1              0,2
# 2                   2                     0,4          1              0,2
# 3                   3                     1,1          0                0
# 4                   5                       1          4              0,8
# ..                ...                     ...        ...              ...
# 486                12                     1,4          2              0,2
# 487                10                     1,1          1              0,1
# 488                16                     1,7          1              0,1
# 489                12                     1,4          4              0,5
# 490              2976                     0,9        616              0,2
#
# [491 rows x 52 columns]

# %%
##trim pre merge
df_bw2017_zst_trimmed = df_bw2017_zst.drop(44) # drop total, we are only interested in local numbers 


df_bw2017_zst_trimmed = df_bw2017_zst_trimmed.drop(columns=['Wahlberechtigte ohne Sperrvermerk',
                               'Wahlberechtigte mit Sperrvermerk',
                               'Wahlberechtigte insgesamt',
                               'Wähler',
                               'darunter Wähler mit Wahlschein',
                               'ungültige Stimmen',
                               'gültige Stimmen',
                               'CDU',
                               'SPD',
                               'GRÜNE',
                               'DIE LINKE',
                               'Die PARTEI',
                               'AfD',
                               'FDP',
                               'PIRATEN',
                               'NPD',
                               'FREIE WÄHLER',
                               'BüSo',
                               'MLPD',
                               'BGE',
                               'DKP',
                               'DM',
                               'ÖDP', 
                               'Tierschutzpartei',
                               'V-Partei³']) #drop total values to only keep relational data

df_bw2017_zst_trimmed = df_bw2017_zst_trimmed.drop(columns=['Anteil Wahlberechtigte mit Sperrvermerk',
                                                            'Anteil Wahlberechtigte insgesamt',
                                                            'Anteil gültige Stimmen']) # redundant infos

# Stadtteilnummer: string -> int
df_bw2017_zst_trimmed['Stadtteilnummer']=df_bw2017_zst_trimmed['Stadtteilnummer'].astype(int)

#convert Strings to Float
for row in list(df_bw2017_zst_trimmed):
    if (row.startswith('Anteil')):
        df_bw2017_zst_trimmed[row] = df_bw2017_zst_trimmed[row].str.replace(',', '.').astype(float)
        
display(df_bw2017_zst_trimmed.dtypes)
df_bw2017_zst_trimmed
#joined = df_bw2017_zst.set_index('Stadtteilname').join(df_arbeitsmarkt.set_index('Stadtteil'))
#joined
# Out:
# Stadtteilnummer                               int64
# Stadtteilname                                object
# Anteil Wahlberechtigte ohne Sperrvermerk    float64
# Anteil Wähler                               float64
# Anteil darunter Wähler mit Wahlschein       float64
# Anteil ungültige Stimmen                    float64
# Anteil CDU                                  float64
# Anteil SPD                                  float64
# Anteil GRÜNE                                float64
# Anteil DIE LINKE                            float64
# Anteil AfD                                  float64
# Anteil FDP                                  float64
# Anteil PIRATEN                              float64
# Anteil NPD                                  float64
# Anteil FREIE WÄHLER                         float64
# Anteil Die PARTEI                           float64
# Anteil BüSo                                 float64
# Anteil MLPD                                 float64
# Anteil BGE                                  float64
# Anteil DKP                                  float64
# Anteil DM                                   float64
# Anteil ÖDP                                  float64
# Anteil Tierschutzpartei                     float64
# Anteil V-Partei³                            float64
# dtype: object
#     Stadtteilnummer             Stadtteilname  \
# 0                 1                  Altstadt
# 1                 2                Innenstadt
# 2                 4               Westend-Süd
# 3                 5              Westend-Nord
# 4                 6              Nordend-West
# 5                 7               Nordend-Ost
# 6                 8                    Ostend
# 7                 9                  Bornheim
# 8                10  Gutleut-/Bahnhofsviertel
# 9                11                    Gallus
# 10               12                Bockenheim
# 11               13        Sachsenhausen-Nord
# 12               14         Sachsenhausen-Süd
# 13               16                   Oberrad
# 14               17                 Niederrad
# 15               18                Schwanheim
# 16               19                 Griesheim
# 17               20                 Rödelheim
# 18               21                    Hausen
# 19               22                 Praunheim
# 20               24               Heddernheim
# 21               25               Niederursel
# 22               26                  Ginnheim
# 23               27                 Dornbusch
# 24               28               Eschersheim
# 25               29                 Eckenheim
# 26               30              Preungesheim
# 27               31                   Bonames
# 28               32               Berkersheim
# 29               33                Riederwald
# 30               34                  Seckbach
# 31               35                Fechenheim
# 32               36                    Höchst
# 33               37                      Nied
# 34               38                Sindlingen
# 35               39                 Zeilsheim
# 36               40           Unterliederbach
# 37               41                Sossenheim
# 38               42          Nieder-Erlenbach
# 39               43          Kalbach-Riedberg
# 40               44                   Harheim
# 41               45           Nieder-Eschbach
# 42               46            Bergen-Enkheim
# 43               47          Frankfurter Berg
#
#     Anteil Wahlberechtigte ohne Sperrvermerk  Anteil Wähler  \
# 0                                       73.2           74.8
# 1                                       71.6           67.6
# 2                                       62.8           84.8
# 3                                       69.3           78.6
# 4                                       67.3           85.0
# 5                                       70.2           82.8
# 6                                       72.1           77.9
# 7                                       74.5           78.1
# 8                                       73.0           74.1
# 9                                       75.3           68.9
# 10                                      72.3           77.2
# 11                                      68.8           81.2
# 12                                      68.2           78.8
# 13                                      78.5           71.6
# 14                                      76.4           70.8
# 15                                      82.1           69.6
# 16                                      85.1           61.3
# 17                                      78.8           73.2
# 18                                      78.3           79.4
# 19                                      79.6           73.1
# 20                                      80.4           72.3
# 21                                      81.7           69.6
# 22                                      79.2           72.4
# 23                                      73.9           80.1
# 24                                      74.2           78.2
# 25                                      80.9           70.2
# 26                                      80.6           75.1
# 27                                      82.5           67.0
# 28                                      76.3           77.8
# 29                                      85.0           67.8
# 30                                      77.8           75.3
# 31                                      83.3           61.2
# 32                                      82.3           66.5
# 33                                      83.2           68.7
# 34                                      85.6           66.6
# 35                                      84.7           67.2
# 36                                      84.9           69.3
# 37                                      84.4           63.3
# 38                                      75.0           84.7
# 39                                      78.3           82.4
# 40                                      76.5           84.1
# 41                                      81.7           71.4
# 42                                      75.9           78.9
# 43                                      81.0           73.1
#
#     Anteil darunter Wähler mit Wahlschein  Anteil ungültige Stimmen  \
# 0                                    34.4                       0.4
# 1                                    40.0                       0.8
# 2                                    42.0                       0.4
# 3                                    37.3                       0.6
# 4                                    37.0                       0.5
# 5                                    34.4                       0.6
# 6                                    34.2                       0.8
# 7                                    31.2                       0.9
# 8                                    34.6                       1.2
# 9                                    34.5                       1.0
# 10                                   32.5                       0.8
# 11                                   36.8                       0.6
# 12                                   38.4                       0.7
# 13                                   28.3                       1.4
# 14                                   31.8                       1.4
# 15                                   24.3                       1.9
# 16                                   22.6                       1.7
# 17                                   27.8                       1.1
# 18                                   35.6                       1.6
# 19                                   26.6                       1.2
# 20                                   25.6                       1.0
# 21                                   24.9                       1.5
# 22                                   27.6                       1.2
# 23                                   31.0                       0.8
# 24                                   31.7                       0.7
# 25                                   25.9                       1.4
# 26                                   24.5                       1.0
# 27                                   25.0                       1.4
# 28                                   29.8                       0.9
# 29                                   20.7                       1.8
# 30                                   27.9                       1.5
# 31                                   25.5                       1.6
# 32                                   24.1                       1.4
# 33                                   22.9                       1.9
# 34                                   20.2                       2.0
# 35                                   21.4                       1.8
# 36                                   20.6                       1.4
# 37                                   22.6                       1.5
# 38                                   28.6                       0.9
# 39                                   25.2                       0.6
# 40                                   26.9                       1.0
# 41                                   24.0                       1.4
# 42                                   29.0                       0.7
# 43                                   25.0                       1.3
#
#     Anteil CDU  Anteil SPD  Anteil GRÜNE  Anteil DIE LINKE  ...  \
# 0         26.3        17.6          14.6              13.0  ...
# 1         26.0        15.3          15.0              13.7  ...
# 2         31.6        11.9          13.6               6.7  ...
# 3         28.7        15.9          16.2               9.4  ...
# 4         25.3        15.6          20.1              12.8  ...
# 5         20.7        17.6          23.6              16.6  ...
# 6         23.7        19.4          18.7              14.2  ...
# 7         22.2        21.4          18.3              16.1  ...
# 8         21.4        15.6          18.4              16.5  ...
# 9         24.4        18.1          13.4              12.7  ...
# 10        22.5        19.0          19.1              14.1  ...
# 11        27.1        15.9          18.6              10.3  ...
# 12        30.2        17.4          13.6               9.1  ...
# 13        27.4        22.5          11.5              11.2  ...
# 14        26.1        22.4          11.9              10.9  ...
# 15        30.6        23.2           9.5               8.7  ...
# 16        25.3        25.6           9.6              11.3  ...
# 17        23.6        21.2          13.9              16.2  ...
# 18        27.5        23.0          13.4              12.6  ...
# 19        24.5        24.3          12.8              12.6  ...
# 20        24.7        24.7          13.3              13.0  ...
# 21        26.2        24.2          12.6              10.8  ...
# 22        23.9        22.6          14.0              14.1  ...
# 23        27.3        19.2          15.2              11.8  ...
# 24        27.6        19.4          15.7              11.5  ...
# 25        24.4        24.1          12.3              14.3  ...
# 26        26.1        21.8          14.2              11.9  ...
# 27        25.7        23.2          12.2              11.7  ...
# 28        29.8        20.5          12.5              11.0  ...
# 29        17.5        29.6           9.7              18.8  ...
# 30        28.3        21.6          14.5              11.1  ...
# 31        24.8        25.6          10.5              12.6  ...
# 32        21.7        23.7          13.7              14.6  ...
# 33        26.7        24.5           8.8              10.5  ...
# 34        29.3        25.9           8.1               9.0  ...
# 35        31.1        24.3           7.8               8.2  ...
# 36        28.6        24.1          10.1              10.2  ...
# 37        30.2        22.7           8.1               9.7  ...
# 38        36.1        17.0          12.9               7.5  ...
# 39        33.6        16.9          12.8               7.2  ...
# 40        33.9        19.0          11.8               7.4  ...
# 41        30.2        21.1          11.1               9.4  ...
# 42        30.4        20.0          11.7               8.5  ...
# 43        28.8        22.0          11.9              10.8  ...
#
#     Anteil FREIE WÄHLER  Anteil Die PARTEI  Anteil BüSo  Anteil MLPD  \
# 0                   0.4                1.9          0.0          0.0
# 1                   0.2                2.0          0.0          0.1
# 2                   0.1                0.6          0.0          0.0
# 3                   0.1                0.7          0.0          0.0
# 4                   0.2                1.2          0.0          0.0
# 5                   0.2                1.6          0.0          0.1
# 6                   0.3                1.5          0.0          0.1
# 7                   0.4                1.5          0.0          0.1
# 8                   0.2                1.9          0.0          0.1
# 9                   0.4                1.5          0.0          0.3
# 10                  0.4                1.5          0.0          0.1
# 11                  0.3                1.1          0.0          0.0
# 12                  0.3                0.8          0.0          0.1
# 13                  0.3                1.2          0.0          0.2
# 14                  0.5                1.6          0.0          0.1
# 15                  0.7                0.9          0.0          0.0
# 16                  0.9                1.4          0.0          0.3
# 17                  0.5                1.7          0.0          0.1
# 18                  0.5                1.1          0.0          0.0
# 19                  0.5                1.0          0.0          0.0
# 20                  0.7                1.0          0.0          0.1
# 21                  0.4                0.9          0.0          0.0
# 22                  0.6                1.4          0.0          0.1
# 23                  0.4                0.8          0.0          0.1
# 24                  0.5                1.0          0.1          0.0
# 25                  0.5                1.4          0.0          0.1
# 26                  0.4                1.2          0.0          0.1
# 27                  0.6                0.9          0.0          0.2
# 28                  0.4                1.1          0.0          0.1
# 29                  0.5                1.4          0.0          0.1
# 30                  0.4                1.2          0.0          0.0
# 31                  0.7                1.4          0.0          0.0
# 32                  0.5                2.1          0.0          0.2
# 33                  0.8                0.8          0.0          0.1
# 34                  0.8                1.0          0.0          0.2
# 35                  0.6                1.0          0.0          0.0
# 36                  0.8                1.4          0.0          0.1
# 37                  0.9                1.2          0.0          0.1
# 38                  0.4                0.6          0.0          0.1
# 39                  0.4                0.9          0.0          0.0
# 40                  0.8                1.2          0.0          0.0
# 41                  0.9                1.2          0.0          0.1
# 42                  0.8                1.0          0.0          0.1
# 43                  0.8                1.2          0.0          0.1
#
#     Anteil BGE  Anteil DKP  Anteil DM  Anteil ÖDP  Anteil Tierschutzpartei  \
# 0          0.3         0.0        0.2         0.3                      0.8
# 1          0.1         0.0        0.4         0.2                      0.7
# 2          0.2         0.0        0.1         0.2                      0.4
# 3          0.1         0.1        0.2         0.1                      0.4
# 4          0.3         0.1        0.1         0.2                      0.6
# 5          0.3         0.0        0.0         0.2                      0.7
# 6          0.3         0.1        0.2         0.2                      0.8
# 7          0.4         0.1        0.1         0.2                      1.0
# 8          0.2         0.0        0.1         0.3                      0.6
# 9          0.3         0.0        0.3         0.2                      0.8
# 10         0.3         0.1        0.1         0.3                      0.7
# 11         0.3         0.0        0.1         0.2                      0.4
# 12         0.2         0.0        0.1         0.2                      0.9
# 13         0.3         0.0        0.2         0.2                      1.2
# 14         0.1         0.1        0.2         0.2                      0.9
# 15         0.2         0.1        0.2         0.1                      1.2
# 16         0.3         0.0        0.3         0.1                      1.5
# 17         0.3         0.1        0.3         0.2                      1.0
# 18         0.4         0.0        0.1         0.1                      0.6
# 19         0.2         0.0        0.2         0.2                      1.3
# 20         0.3         0.0        0.1         0.1                      1.1
# 21         0.2         0.0        0.1         0.2                      1.1
# 22         0.2         0.0        0.3         0.4                      1.0
# 23         0.2         0.0        0.2         0.2                      0.8
# 24         0.3         0.1        0.1         0.2                      1.0
# 25         0.3         0.1        0.3         0.2                      1.6
# 26         0.4         0.1        0.1         0.2                      1.1
# 27         0.1         0.1        0.2         0.2                      1.3
# 28         0.2         0.0        0.1         0.2                      0.6
# 29         0.2         0.2        0.1         0.3                      2.0
# 30         0.2         0.1        0.2         0.1                      1.1
# 31         0.4         0.1        0.2         0.1                      1.5
# 32         0.3         0.1        0.3         0.3                      1.1
# 33         0.1         0.0        0.5         0.2                      1.5
# 34         0.2         0.1        0.4         0.1                      1.6
# 35         0.2         0.0        0.6         0.0                      1.6
# 36         0.3         0.1        0.2         0.1                      1.2
# 37         0.2         0.0        0.4         0.2                      1.6
# 38         0.0         0.0        0.1         0.3                      1.2
# 39         0.2         0.0        0.1         0.2                      1.0
# 40         0.1         0.1        0.2         0.1                      1.4
# 41         0.3         0.0        0.1         0.2                      1.0
# 42         0.2         0.0        0.2         0.1                      1.1
# 43         0.2         0.0        0.2         0.1                      0.8
#
#     Anteil V-Partei³
# 0                0.2
# 1                0.4
# 2                0.2
# 3                0.2
# 4                0.2
# 5                0.2
# 6                0.2
# 7                0.2
# 8                0.2
# 9                0.2
# 10               0.2
# 11               0.2
# 12               0.2
# 13               0.2
# 14               0.2
# 15               0.2
# 16               0.1
# 17               0.3
# 18               0.1
# 19               0.2
# 20               0.1
# 21               0.2
# 22               0.2
# 23               0.2
# 24               0.2
# 25               0.4
# 26               0.3
# 27               0.5
# 28               0.2
# 29               0.1
# 30               0.1
# 31               0.2
# 32               0.1
# 33               0.2
# 34               0.2
# 35               0.1
# 36               0.1
# 37               0.2
# 38               0.1
# 39               0.3
# 40               0.4
# 41               0.2
# 42               0.2
# 43               0.3
#
# [44 rows x 24 columns]

# %%
df_arbeitsmarkt = pd.read_json("./data/arbeitsmarkt.json")


# drop gesamt
df_arbeitsmarkt.drop(45, inplace=True)    

##split 2011 <-> 2012
l2011 = list()
l2012 = list()
lother = list()
for row in list(df_arbeitsmarkt):
    if row.endswith('2011'):
        l2011.append(row)
    elif row.endswith('2012'):
        l2012.append(row)
    elif row == 'Stadtteil':
        pass
    else:
        lother.append(row)

df_arbeitsmarkt_2011 = df_arbeitsmarkt['Stadtteil'].copy().to_frame()
df_arbeitsmarkt_2011['year'] = 2011
df_arbeitsmarkt_2012 = df_arbeitsmarkt['Stadtteil'].copy().to_frame()
df_arbeitsmarkt_2012['year'] = 2012


#display(df_arbeitsmarkt)
#for row in lother:
#    df_arbeitsmarkt_2011[row.strip().replace('\xa0', ' ')] = df_arbeitsmarkt[row].copy()
#    df_arbeitsmarkt_2012[row.strip().replace('\xa0', ' ')] = df_arbeitsmarkt[row].copy() 

for row in l2011:
    df_arbeitsmarkt_2011[row[:-6].strip().replace('\xa0', ' ')] = df_arbeitsmarkt[row].copy()
for row in l2012:
    df_arbeitsmarkt_2012[row[:-6].strip().replace('\xa0', ' ')] = df_arbeitsmarkt[row].copy()

# %%
# preprocessing arbeitsmarkt
def preprocess(df_old):
    #display(list(df_old))
    #Jeweils Anteil an Gesamtbevölkerung
    df = pd.DataFrame(index=df_old.index)
    df['Stadtteil'] = df_old['Stadtteil']
    df['Erwerbsfähigendichte'] = df_old['Erwerbsfähige Personen Erwerbsfähigendichte in %'].str.replace(',', '.').astype(float)/100
    #Erwerbsfähige Männer / alle
    df['Erwerbsfähige Männer'] = 1.0*df_old['Erwerbsfähige Personen Männer']/df_old['Erwerbsfähige Personen Insgesamt']
    df['Erwerbsfähige Deutsche'] = 1.0*df_old['Erwerbsfähige Personen Deutsche']/df_old['Erwerbsfähige Personen Insgesamt']
    df['Beschäftigtendichte'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte in %'].str.replace(',', '.').astype(float)/100.0
    df['Beschäftigtendichte Männer'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte Männer in %'].str.replace(',', '.').astype(float)/100.0
    df['Beschäftigtendichte Frauen'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte Frauen in %'].str.replace(',', '.').astype(float)/100.0
    df['Beschäftigtendichte Deutsche'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte Deutsche in %'].str.replace(',', '.').astype(float)/100.0
    df['Beschäftigtendichte Ausländer'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte Ausländerinnen und Ausländer in %'].str.replace(',', '.').astype(float)/100.0
    df['Beschäftigtendichte 15-25-Jährige'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Beschäftigtendichte 15- bis unter 25-Jährige in %'].str.replace(',', '.').astype(float)/100.0 
    df['Nebenjobdichte'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Nebenjobdichte in %'].str.replace(',', '.').astype(float)/100.0
    df['Midijobdichte'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Midijobdichte in %'].str.replace(',', '.').astype(float)/100.0
    df['Minijobdichte'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Minijobdichte in %'].str.replace(',', '.').astype(float)/100.0
    df['Minijobdichte_test'] = df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Minijobber/innen']/df_old['Sozialversicherungspflichtig Beschäftigte (Wohnort) Insgesamt']
    df['Arbeitslosendichte'] = df_old['Arbeitslose Arbeitslosendichte in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte SGB III'] = df_old['Arbeitslose Arbeitslosendichte SGB III in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte SGB II'] = df_old['Arbeitslose Arbeitslosendichte SGB II in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte Frauen'] = df_old['Arbeitslose Arbeitslosendichte Frauen in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte Männer'] = df_old['Arbeitslose Arbeitslosendichte Männer in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte unter 25-Jährige'] = df_old['Arbeitslose Arbeitslosendichte unter 25-Jährige in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte Deutsche'] = df_old['Arbeitslose Arbeitslosendichte Deutsche in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte Ausländer'] = df_old['Arbeitslose Arbeitslosendichte Ausländerinnen und Ausländer in %'].str.replace(',', '.').astype(float)/100.0
    df['Arbeitslosendichte 55- bis unter 65-Jährige'] = df_old['Arbeitslose Arbeitslosendichte 55- bis unter 65-Jährige in %'].str.replace(',', '.').astype(float)/100.0
    return df
df_arbeitsmarkt_2011_preprocessed = preprocess(df_arbeitsmarkt_2011)
df_arbeitsmarkt_2012_preprocessed = preprocess(df_arbeitsmarkt_2012)
df_arbeitsmarkt_2011_preprocessed.head()
# Out:
#          Stadtteil  Erwerbsfähigendichte  Erwerbsfähige Männer  \
# 0         Altstadt                 0.742              0.516743
# 1       Innenstadt                 0.777              0.565702
# 2  Bahnhofsviertel                 0.870              0.612959
# 3      Westend-Süd                 0.723              0.503553
# 4     Westend-Nord                 0.710              0.492967
#
#    Erwerbsfähige Deutsche  Beschäftigtendichte  Beschäftigtendichte Männer  \
# 0                0.610350                0.517                       0.561
# 1                0.526033                0.511                       0.537
# 2                0.485097                0.446                       0.457
# 3                0.735994                0.535                       0.557
# 4                0.708972                0.505                       0.526
#
#    Beschäftigtendichte Frauen  Beschäftigtendichte Deutsche  \
# 0                       0.470                         0.582
# 1                       0.478                         0.604
# 2                       0.429                         0.571
# 3                       0.512                         0.587
# 4                       0.485                         0.550
#
#    Beschäftigtendichte Ausländer  Beschäftigtendichte 15-25-Jährige  ...  \
# 0                          0.416                              0.310  ...
# 1                          0.408                              0.358  ...
# 2                          0.328                              0.274  ...
# 3                          0.389                              0.208  ...
# 4                          0.395                              0.239  ...
#
#    Minijobdichte_test  Arbeitslosendichte  Arbeitslosendichte SGB III  \
# 0            0.128771               0.055                       0.016
# 1            0.149091               0.083                       0.014
# 2            0.148256               0.077                       0.009
# 3            0.083771               0.020                       0.012
# 4            0.119777               0.034                       0.012
#
#    Arbeitslosendichte SGB II  Arbeitslosendichte Frauen  \
# 0                      0.040                      0.065
# 1                      0.069                      0.059
# 2                      0.068                      0.040
# 3                      0.008                      0.017
# 4                      0.022                      0.032
#
#    Arbeitslosendichte Männer  Arbeitslosendichte unter 25-Jährige  \
# 0                      0.046                                0.017
# 1                      0.102                                0.043
# 2                      0.100                                0.052
# 3                      0.024                                0.006
# 4                      0.037                                0.020
#
#    Arbeitslosendichte Deutsche  Arbeitslosendichte Ausländer  \
# 0                        0.050                         0.063
# 1                        0.083                         0.083
# 2                        0.085                         0.068
# 3                        0.019                         0.024
# 4                        0.028                         0.050
#
#    Arbeitslosendichte 55- bis unter 65-Jährige
# 0                                        0.068
# 1                                        0.089
# 2                                        0.091
# 3                                        0.026
# 4                                        0.042
#
# [5 rows x 23 columns]

# %%
#Problem:
#Wahldaten fassen Bahnhof- und Gutleutviertel zusamme. Um so wenig Daten wie möglich zu verlieren,
#legen wir für die Wahl beide Beobachtungen mit den selben Werten an

def solve_prolem(df_old):
    df = df_old.copy()
    df.drop(df.index[df.Stadtteilname == 'Gutleut-/Bahnhofsviertel'], inplace=True)
    series = df_old[df_old.Stadtteilname == 'Gutleut-/Bahnhofsviertel'].iloc[0,:]
    bahnhof = series.copy()
    bahnhof['Stadtteilname'] = 'Bahnhofsviertel'
    gutleut = series.copy()
    gutleut['Stadtteilname'] = 'Gutleutviertel'
    df = df.append([gutleut,bahnhof])
    return df


df_bw2017_zst_preprocessed = solve_prolem(df_bw2017_zst_trimmed)
df_bw2017_zst_preprocessed.head()
# Out:
#    Stadtteilnummer Stadtteilname  Anteil Wahlberechtigte ohne Sperrvermerk  \
# 0                1      Altstadt                                      73.2
# 1                2    Innenstadt                                      71.6
# 2                4   Westend-Süd                                      62.8
# 3                5  Westend-Nord                                      69.3
# 4                6  Nordend-West                                      67.3
#
#    Anteil Wähler  Anteil darunter Wähler mit Wahlschein  \
# 0           74.8                                   34.4
# 1           67.6                                   40.0
# 2           84.8                                   42.0
# 3           78.6                                   37.3
# 4           85.0                                   37.0
#
#    Anteil ungültige Stimmen  Anteil CDU  Anteil SPD  Anteil GRÜNE  \
# 0                       0.4        26.3        17.6          14.6
# 1                       0.8        26.0        15.3          15.0
# 2                       0.4        31.6        11.9          13.6
# 3                       0.6        28.7        15.9          16.2
# 4                       0.5        25.3        15.6          20.1
#
#    Anteil DIE LINKE  ...  Anteil FREIE WÄHLER  Anteil Die PARTEI  Anteil BüSo  \
# 0              13.0  ...                  0.4                1.9          0.0
# 1              13.7  ...                  0.2                2.0          0.0
# 2               6.7  ...                  0.1                0.6          0.0
# 3               9.4  ...                  0.1                0.7          0.0
# 4              12.8  ...                  0.2                1.2          0.0
#
#    Anteil MLPD  Anteil BGE  Anteil DKP  Anteil DM  Anteil ÖDP  \
# 0          0.0         0.3         0.0        0.2         0.3
# 1          0.1         0.1         0.0        0.4         0.2
# 2          0.0         0.2         0.0        0.1         0.2
# 3          0.0         0.1         0.1        0.2         0.1
# 4          0.0         0.3         0.1        0.1         0.2
#
#    Anteil Tierschutzpartei  Anteil V-Partei³
# 0                      0.8               0.2
# 1                      0.7               0.4
# 2                      0.4               0.2
# 3                      0.4               0.2
# 4                      0.6               0.2
#
# [5 rows x 24 columns]

# %%
merge_2011 = df_arbeitsmarkt_2011_preprocessed.set_index('Stadtteil').join(df_bw2017_zst_preprocessed.set_index('Stadtteilname'))
merge_2012 = df_arbeitsmarkt_2012_preprocessed.set_index('Stadtteil').join(df_bw2017_zst_preprocessed.set_index('Stadtteilname'))
merge_2011.to_pickle("./data2011.pkl")
merge_2012.to_pickle("./data2012.pkl")
merge_2011
# Out:
#                     Erwerbsfähigendichte  Erwerbsfähige Männer  \
# Stadtteil
# Altstadt                           0.742              0.516743
# Innenstadt                         0.777              0.565702
# Bahnhofsviertel                    0.870              0.612959
# Westend-Süd                        0.723              0.503553
# Westend-Nord                       0.710              0.492967
# Nordend-West                       0.742              0.492733
# Nordend-Ost                        0.767              0.485901
# Ostend                             0.735              0.501873
# Bornheim                           0.708              0.478778
# Gutleutviertel                     0.761              0.569850
# Gallus                             0.759              0.547639
# Bockenheim                         0.765              0.501021
# Sachsenhausen-Nord                 0.735              0.495810
# Sachsenhausen-Süd                  0.670              0.493794
# Oberrad                            0.692              0.504082
# Niederrad                          0.712              0.502510
# Schwanheim                         0.639              0.498026
# Griesheim                          0.723              0.573227
# Rödelheim                          0.694              0.503244
# Hausen                             0.681              0.496970
# Praunheim                          0.650              0.486884
# Heddernheim                        0.662              0.479153
# Niederursel                        0.629              0.495432
# Ginnheim                           0.674              0.477814
# Dornbusch                          0.654              0.475264
# Eschersheim                        0.680              0.480827
# Eckenheim                          0.685              0.492332
# Preungesheim                       0.672              0.490979
# Bonames                            0.666              0.495943
# Berkersheim                        0.646              0.481498
# Riederwald                         0.681              0.498427
# Seckbach                           0.643              0.512812
# Fechenheim                         0.679              0.520075
# Höchst                             0.734              0.518482
# Nied                               0.685              0.511240
# Sindlingen                         0.666              0.530020
# Zeilsheim                          0.644              0.502714
# Unterliederbach                    0.677              0.497464
# Sossenheim                         0.674              0.506726
# Nieder-Erlenbach                   0.655              0.494935
# Kalbach-Riedberg                   0.692              0.497468
# Harheim                            0.656              0.487822
# Nieder-Eschbach                    0.664              0.489684
# Bergen-Enkheim                     0.663              0.490139
# Frankfurter Berg                   0.698              0.494591
#
#                     Erwerbsfähige Deutsche  Beschäftigtendichte  \
# Stadtteil
# Altstadt                          0.610350                0.517
# Innenstadt                        0.526033                0.511
# Bahnhofsviertel                   0.485097                0.446
# Westend-Süd                       0.735994                0.535
# Westend-Nord                      0.708972                0.505
# Nordend-West                      0.779906                0.550
# Nordend-Ost                       0.772343                0.570
# Ostend                            0.685517                0.544
# Bornheim                          0.742741                0.568
# Gutleutviertel                    0.589523                0.514
# Gallus                            0.537797                0.489
# Bockenheim                        0.690393                0.544
# Sachsenhausen-Nord                0.735633                0.538
# Sachsenhausen-Süd                 0.748770                0.515
# Oberrad                           0.687077                0.503
# Niederrad                         0.659549                0.544
# Schwanheim                        0.742395                0.525
# Griesheim                         0.552567                0.480
# Rödelheim                         0.677138                0.515
# Hausen                            0.624660                0.447
# Praunheim                         0.735095                0.509
# Heddernheim                       0.746026                0.530
# Niederursel                       0.705651                0.487
# Ginnheim                          0.732108                0.498
# Dornbusch                         0.756617                0.520
# Eschersheim                       0.779018                0.524
# Eckenheim                         0.680543                0.499
# Preungesheim                      0.683278                0.510
# Bonames                           0.748217                0.494
# Berkersheim                       0.800713                0.484
# Riederwald                        0.713027                0.494
# Seckbach                          0.726297                0.500
# Fechenheim                        0.564562                0.441
# Höchst                            0.579526                0.492
# Nied                              0.624778                0.500
# Sindlingen                        0.674186                0.508
# Zeilsheim                         0.703024                0.513
# Unterliederbach                   0.687506                0.526
# Sossenheim                        0.655586                0.491
# Nieder-Erlenbach                  0.865176                0.520
# Kalbach-Riedberg                  0.804782                0.538
# Harheim                           0.859241                0.572
# Nieder-Eschbach                   0.784030                0.516
# Bergen-Enkheim                    0.805529                0.521
# Frankfurter Berg                  0.720820                0.486
#
#                     Beschäftigtendichte Männer  Beschäftigtendichte Frauen  \
# Stadtteil
# Altstadt                                 0.561                       0.470
# Innenstadt                               0.537                       0.478
# Bahnhofsviertel                          0.457                       0.429
# Westend-Süd                              0.557                       0.512
# Westend-Nord                             0.526                       0.485
# Nordend-West                             0.546                       0.554
# Nordend-Ost                              0.565                       0.574
# Ostend                                   0.544                       0.544
# Bornheim                                 0.567                       0.568
# Gutleutviertel                           0.531                       0.492
# Gallus                                   0.510                       0.464
# Bockenheim                               0.557                       0.530
# Sachsenhausen-Nord                       0.544                       0.531
# Sachsenhausen-Süd                        0.526                       0.504
# Oberrad                                  0.505                       0.501
# Niederrad                                0.558                       0.529
# Schwanheim                               0.572                       0.478
# Griesheim                                0.501                       0.452
# Rödelheim                                0.531                       0.498
# Hausen                                   0.478                       0.417
# Praunheim                                0.534                       0.485
# Heddernheim                              0.562                       0.501
# Niederursel                              0.521                       0.454
# Ginnheim                                 0.527                       0.472
# Dornbusch                                0.527                       0.513
# Eschersheim                              0.535                       0.514
# Eckenheim                                0.513                       0.486
# Preungesheim                             0.534                       0.487
# Bonames                                  0.523                       0.465
# Berkersheim                              0.510                       0.459
# Riederwald                               0.532                       0.456
# Seckbach                                 0.484                       0.517
# Fechenheim                               0.466                       0.414
# Höchst                                   0.507                       0.476
# Nied                                     0.531                       0.469
# Sindlingen                               0.551                       0.460
# Zeilsheim                                0.570                       0.455
# Unterliederbach                          0.566                       0.487
# Sossenheim                               0.533                       0.448
# Nieder-Erlenbach                         0.548                       0.492
# Kalbach-Riedberg                         0.553                       0.522
# Harheim                                  0.601                       0.545
# Nieder-Eschbach                          0.552                       0.483
# Bergen-Enkheim                           0.523                       0.519
# Frankfurter Berg                         0.512                       0.460
#
#                     Beschäftigtendichte Deutsche  \
# Stadtteil
# Altstadt                                   0.582
# Innenstadt                                 0.604
# Bahnhofsviertel                            0.571
# Westend-Süd                                0.587
# Westend-Nord                               0.550
# Nordend-West                               0.588
# Nordend-Ost                                0.606
# Ostend                                     0.606
# Bornheim                                   0.609
# Gutleutviertel                             0.598
# Gallus                                     0.571
# Bockenheim                                 0.600
# Sachsenhausen-Nord                         0.587
# Sachsenhausen-Süd                          0.554
# Oberrad                                    0.558
# Niederrad                                  0.599
# Schwanheim                                 0.560
# Griesheim                                  0.569
# Rödelheim                                  0.570
# Hausen                                     0.503
# Praunheim                                  0.548
# Heddernheim                                0.568
# Niederursel                                0.521
# Ginnheim                                   0.521
# Dornbusch                                  0.547
# Eschersheim                                0.558
# Eckenheim                                  0.542
# Preungesheim                               0.554
# Bonames                                    0.525
# Berkersheim                                0.510
# Riederwald                                 0.534
# Seckbach                                   0.547
# Fechenheim                                 0.503
# Höchst                                     0.571
# Nied                                       0.567
# Sindlingen                                 0.569
# Zeilsheim                                  0.556
# Unterliederbach                            0.570
# Sossenheim                                 0.553
# Nieder-Erlenbach                           0.540
# Kalbach-Riedberg                           0.572
# Harheim                                    0.595
# Nieder-Eschbach                            0.542
# Bergen-Enkheim                             0.545
# Frankfurter Berg                           0.513
#
#                     Beschäftigtendichte Ausländer  \
# Stadtteil
# Altstadt                                    0.416
# Innenstadt                                  0.408
# Bahnhofsviertel                             0.328
# Westend-Süd                                 0.389
# Westend-Nord                                0.395
# Nordend-West                                0.416
# Nordend-Ost                                 0.447
# Ostend                                      0.408
# Bornheim                                    0.449
# Gutleutviertel                              0.393
# Gallus                                      0.394
# Bockenheim                                  0.418
# Sachsenhausen-Nord                          0.401
# Sachsenhausen-Süd                           0.397
# Oberrad                                     0.382
# Niederrad                                   0.437
# Schwanheim                                  0.421
# Griesheim                                   0.370
# Rödelheim                                   0.400
# Hausen                                      0.356
# Praunheim                                   0.400
# Heddernheim                                 0.417
# Niederursel                                 0.406
# Ginnheim                                    0.437
# Dornbusch                                   0.434
# Eschersheim                                 0.403
# Eckenheim                                   0.408
# Preungesheim                                0.414
# Bonames                                     0.402
# Berkersheim                                 0.378
# Riederwald                                  0.396
# Seckbach                                    0.376
# Fechenheim                                  0.361
# Höchst                                      0.385
# Nied                                        0.389
# Sindlingen                                  0.382
# Zeilsheim                                   0.410
# Unterliederbach                             0.429
# Sossenheim                                  0.375
# Nieder-Erlenbach                            0.389
# Kalbach-Riedberg                            0.396
# Harheim                                     0.430
# Nieder-Eschbach                             0.423
# Bergen-Enkheim                              0.423
# Frankfurter Berg                            0.417
#
#                     Beschäftigtendichte 15-25-Jährige  Nebenjobdichte  ...  \
# Stadtteil                                                              ...
# Altstadt                                        0.310           0.044  ...
# Innenstadt                                      0.358           0.051  ...
# Bahnhofsviertel                                 0.274           0.049  ...
# Westend-Süd                                     0.208           0.024  ...
# Westend-Nord                                    0.239           0.040  ...
# Nordend-West                                    0.272           0.037  ...
# Nordend-Ost                                     0.268           0.039  ...
# Ostend                                          0.301           0.051  ...
# Bornheim                                        0.308           0.048  ...
# Gutleutviertel                                  0.284           0.054  ...
# Gallus                                          0.316           0.063  ...
# Bockenheim                                      0.268           0.046  ...
# Sachsenhausen-Nord                              0.283           0.044  ...
# Sachsenhausen-Süd                               0.250           0.039  ...
# Oberrad                                         0.302           0.060  ...
# Niederrad                                       0.328           0.061  ...
# Schwanheim                                      0.352           0.054  ...
# Griesheim                                       0.331           0.060  ...
# Rödelheim                                       0.302           0.052  ...
# Hausen                                          0.229           0.055  ...
# Praunheim                                       0.308           0.061  ...
# Heddernheim                                     0.345           0.058  ...
# Niederursel                                     0.273           0.056  ...
# Ginnheim                                        0.280           0.054  ...
# Dornbusch                                       0.250           0.047  ...
# Eschersheim                                     0.271           0.050  ...
# Eckenheim                                       0.282           0.062  ...
# Preungesheim                                    0.290           0.064  ...
# Bonames                                         0.304           0.059  ...
# Berkersheim                                     0.283           0.046  ...
# Riederwald                                      0.343           0.057  ...
# Seckbach                                        0.332           0.055  ...
# Fechenheim                                      0.316           0.062  ...
# Höchst                                          0.310           0.062  ...
# Nied                                            0.328           0.059  ...
# Sindlingen                                      0.348           0.061  ...
# Zeilsheim                                       0.369           0.060  ...
# Unterliederbach                                 0.339           0.063  ...
# Sossenheim                                      0.343           0.064  ...
# Nieder-Erlenbach                                0.264           0.040  ...
# Kalbach-Riedberg                                0.259           0.041  ...
# Harheim                                         0.332           0.049  ...
# Nieder-Eschbach                                 0.300           0.057  ...
# Bergen-Enkheim                                  0.287           0.052  ...
# Frankfurter Berg                                0.266           0.060  ...
#
#                     Anteil FREIE WÄHLER  Anteil Die PARTEI  Anteil BüSo  \
# Stadtteil
# Altstadt                            0.4                1.9          0.0
# Innenstadt                          0.2                2.0          0.0
# Bahnhofsviertel                     0.2                1.9          0.0
# Westend-Süd                         0.1                0.6          0.0
# Westend-Nord                        0.1                0.7          0.0
# Nordend-West                        0.2                1.2          0.0
# Nordend-Ost                         0.2                1.6          0.0
# Ostend                              0.3                1.5          0.0
# Bornheim                            0.4                1.5          0.0
# Gutleutviertel                      0.2                1.9          0.0
# Gallus                              0.4                1.5          0.0
# Bockenheim                          0.4                1.5          0.0
# Sachsenhausen-Nord                  0.3                1.1          0.0
# Sachsenhausen-Süd                   0.3                0.8          0.0
# Oberrad                             0.3                1.2          0.0
# Niederrad                           0.5                1.6          0.0
# Schwanheim                          0.7                0.9          0.0
# Griesheim                           0.9                1.4          0.0
# Rödelheim                           0.5                1.7          0.0
# Hausen                              0.5                1.1          0.0
# Praunheim                           0.5                1.0          0.0
# Heddernheim                         0.7                1.0          0.0
# Niederursel                         0.4                0.9          0.0
# Ginnheim                            0.6                1.4          0.0
# Dornbusch                           0.4                0.8          0.0
# Eschersheim                         0.5                1.0          0.1
# Eckenheim                           0.5                1.4          0.0
# Preungesheim                        0.4                1.2          0.0
# Bonames                             0.6                0.9          0.0
# Berkersheim                         0.4                1.1          0.0
# Riederwald                          0.5                1.4          0.0
# Seckbach                            0.4                1.2          0.0
# Fechenheim                          0.7                1.4          0.0
# Höchst                              0.5                2.1          0.0
# Nied                                0.8                0.8          0.0
# Sindlingen                          0.8                1.0          0.0
# Zeilsheim                           0.6                1.0          0.0
# Unterliederbach                     0.8                1.4          0.0
# Sossenheim                          0.9                1.2          0.0
# Nieder-Erlenbach                    0.4                0.6          0.0
# Kalbach-Riedberg                    0.4                0.9          0.0
# Harheim                             0.8                1.2          0.0
# Nieder-Eschbach                     0.9                1.2          0.0
# Bergen-Enkheim                      0.8                1.0          0.0
# Frankfurter Berg                    0.8                1.2          0.0
#
#                     Anteil MLPD  Anteil BGE  Anteil DKP  Anteil DM  \
# Stadtteil
# Altstadt                    0.0         0.3         0.0        0.2
# Innenstadt                  0.1         0.1         0.0        0.4
# Bahnhofsviertel             0.1         0.2         0.0        0.1
# Westend-Süd                 0.0         0.2         0.0        0.1
# Westend-Nord                0.0         0.1         0.1        0.2
# Nordend-West                0.0         0.3         0.1        0.1
# Nordend-Ost                 0.1         0.3         0.0        0.0
# Ostend                      0.1         0.3         0.1        0.2
# Bornheim                    0.1         0.4         0.1        0.1
# Gutleutviertel              0.1         0.2         0.0        0.1
# Gallus                      0.3         0.3         0.0        0.3
# Bockenheim                  0.1         0.3         0.1        0.1
# Sachsenhausen-Nord          0.0         0.3         0.0        0.1
# Sachsenhausen-Süd           0.1         0.2         0.0        0.1
# Oberrad                     0.2         0.3         0.0        0.2
# Niederrad                   0.1         0.1         0.1        0.2
# Schwanheim                  0.0         0.2         0.1        0.2
# Griesheim                   0.3         0.3         0.0        0.3
# Rödelheim                   0.1         0.3         0.1        0.3
# Hausen                      0.0         0.4         0.0        0.1
# Praunheim                   0.0         0.2         0.0        0.2
# Heddernheim                 0.1         0.3         0.0        0.1
# Niederursel                 0.0         0.2         0.0        0.1
# Ginnheim                    0.1         0.2         0.0        0.3
# Dornbusch                   0.1         0.2         0.0        0.2
# Eschersheim                 0.0         0.3         0.1        0.1
# Eckenheim                   0.1         0.3         0.1        0.3
# Preungesheim                0.1         0.4         0.1        0.1
# Bonames                     0.2         0.1         0.1        0.2
# Berkersheim                 0.1         0.2         0.0        0.1
# Riederwald                  0.1         0.2         0.2        0.1
# Seckbach                    0.0         0.2         0.1        0.2
# Fechenheim                  0.0         0.4         0.1        0.2
# Höchst                      0.2         0.3         0.1        0.3
# Nied                        0.1         0.1         0.0        0.5
# Sindlingen                  0.2         0.2         0.1        0.4
# Zeilsheim                   0.0         0.2         0.0        0.6
# Unterliederbach             0.1         0.3         0.1        0.2
# Sossenheim                  0.1         0.2         0.0        0.4
# Nieder-Erlenbach            0.1         0.0         0.0        0.1
# Kalbach-Riedberg            0.0         0.2         0.0        0.1
# Harheim                     0.0         0.1         0.1        0.2
# Nieder-Eschbach             0.1         0.3         0.0        0.1
# Bergen-Enkheim              0.1         0.2         0.0        0.2
# Frankfurter Berg            0.1         0.2         0.0        0.2
#
#                     Anteil ÖDP  Anteil Tierschutzpartei  Anteil V-Partei³
# Stadtteil
# Altstadt                   0.3                      0.8               0.2
# Innenstadt                 0.2                      0.7               0.4
# Bahnhofsviertel            0.3                      0.6               0.2
# Westend-Süd                0.2                      0.4               0.2
# Westend-Nord               0.1                      0.4               0.2
# Nordend-West               0.2                      0.6               0.2
# Nordend-Ost                0.2                      0.7               0.2
# Ostend                     0.2                      0.8               0.2
# Bornheim                   0.2                      1.0               0.2
# Gutleutviertel             0.3                      0.6               0.2
# Gallus                     0.2                      0.8               0.2
# Bockenheim                 0.3                      0.7               0.2
# Sachsenhausen-Nord         0.2                      0.4               0.2
# Sachsenhausen-Süd          0.2                      0.9               0.2
# Oberrad                    0.2                      1.2               0.2
# Niederrad                  0.2                      0.9               0.2
# Schwanheim                 0.1                      1.2               0.2
# Griesheim                  0.1                      1.5               0.1
# Rödelheim                  0.2                      1.0               0.3
# Hausen                     0.1                      0.6               0.1
# Praunheim                  0.2                      1.3               0.2
# Heddernheim                0.1                      1.1               0.1
# Niederursel                0.2                      1.1               0.2
# Ginnheim                   0.4                      1.0               0.2
# Dornbusch                  0.2                      0.8               0.2
# Eschersheim                0.2                      1.0               0.2
# Eckenheim                  0.2                      1.6               0.4
# Preungesheim               0.2                      1.1               0.3
# Bonames                    0.2                      1.3               0.5
# Berkersheim                0.2                      0.6               0.2
# Riederwald                 0.3                      2.0               0.1
# Seckbach                   0.1                      1.1               0.1
# Fechenheim                 0.1                      1.5               0.2
# Höchst                     0.3                      1.1               0.1
# Nied                       0.2                      1.5               0.2
# Sindlingen                 0.1                      1.6               0.2
# Zeilsheim                  0.0                      1.6               0.1
# Unterliederbach            0.1                      1.2               0.1
# Sossenheim                 0.2                      1.6               0.2
# Nieder-Erlenbach           0.3                      1.2               0.1
# Kalbach-Riedberg           0.2                      1.0               0.3
# Harheim                    0.1                      1.4               0.4
# Nieder-Eschbach            0.2                      1.0               0.2
# Bergen-Enkheim             0.1                      1.1               0.2
# Frankfurter Berg           0.1                      0.8               0.3
#
# [45 rows x 45 columns]

# %%
#import sys
#!{sys.executable} --version
#!{sys.executable} -m pip install git+https://github.com/pandas-profiling/pandas-profiling.git

# %%
from pandas_profiling import ProfileReport
profile2011 = ProfileReport(merge_2011, title="Pandas Profiling Report: 2011")
profile2011.to_file("report_2011.html")
profile2012 = ProfileReport(merge_2011, title="Pandas Profiling Report: 2012")
profile2012.to_file("report_2012.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=60.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=60.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…
