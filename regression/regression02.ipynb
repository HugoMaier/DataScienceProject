# %%
import pandas as pd
data = pd.read_pickle(r"D:/Uni/SS20/DataScience1/project/DataScienceProject/data_other.pkl")
data.head()
# Out:
#                  Anteil Bruttoarbeitsentgelt bis 2.000  \
# Stadtteil
# Altstadt                                      0.237559
# Innenstadt                                    0.292273
# Bahnhofsviertel                                    NaN
# Westend-Süd                                   0.085496
# Westend-Nord                                  0.153124
#
#                  Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000  \
# Stadtteil
# Altstadt                                                 0.398122
# Innenstadt                                               0.387458
# Bahnhofsviertel                                               NaN
# Westend-Süd                                              0.238550
# Westend-Nord                                             0.309922
#
#                  Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000  \
# Stadtteil
# Altstadt                                                 0.141784
# Innenstadt                                               0.106383
# Bahnhofsviertel                                               NaN
# Westend-Süd                                              0.139122
# Westend-Nord                                             0.149040
#
#                  Anteil Bruttoarbeitsentgelt über 5.000  \
# Stadtteil
# Altstadt                                       0.222535
# Innenstadt                                     0.213886
# Bahnhofsviertel                                     NaN
# Westend-Süd                                    0.536832
# Westend-Nord                                   0.387913
#
#                  Median Bruttoarbeitsentgelte  Stadtteilnummer  \
# Stadtteil
# Altstadt                               3270.0                1
# Innenstadt                             2932.0                2
# Bahnhofsviertel                           NaN               10
# Westend-Süd                            5247.0                4
# Westend-Nord                           4236.0                5
#
#                  Anteil Wahlberechtigte ohne Sperrvermerk  Anteil Wähler  \
# Stadtteil
# Altstadt                                             73.2           74.8
# Innenstadt                                           71.6           67.6
# Bahnhofsviertel                                      73.0           74.1
# Westend-Süd                                          62.8           84.8
# Westend-Nord                                         69.3           78.6
#
#                  Anteil darunter Wähler mit Wahlschein  \
# Stadtteil
# Altstadt                                          34.4
# Innenstadt                                        40.0
# Bahnhofsviertel                                   34.6
# Westend-Süd                                       42.0
# Westend-Nord                                      37.3
#
#                  Anteil ungültige Stimmen  ...  Anteil FREIE WÄHLER  \
# Stadtteil                                  ...
# Altstadt                              0.4  ...                  0.4
# Innenstadt                            0.8  ...                  0.2
# Bahnhofsviertel                       1.2  ...                  0.2
# Westend-Süd                           0.4  ...                  0.1
# Westend-Nord                          0.6  ...                  0.1
#
#                  Anteil Die PARTEI  Anteil BüSo  Anteil MLPD  Anteil BGE  \
# Stadtteil
# Altstadt                       1.9          0.0          0.0         0.3
# Innenstadt                     2.0          0.0          0.1         0.1
# Bahnhofsviertel                1.9          0.0          0.1         0.2
# Westend-Süd                    0.6          0.0          0.0         0.2
# Westend-Nord                   0.7          0.0          0.0         0.1
#
#                  Anteil DKP  Anteil DM  Anteil ÖDP  Anteil Tierschutzpartei  \
# Stadtteil
# Altstadt                0.0        0.2         0.3                      0.8
# Innenstadt              0.0        0.4         0.2                      0.7
# Bahnhofsviertel         0.0        0.1         0.3                      0.6
# Westend-Süd             0.0        0.1         0.2                      0.4
# Westend-Nord            0.1        0.2         0.1                      0.4
#
#                  Anteil V-Partei³
# Stadtteil
# Altstadt                      0.2
# Innenstadt                    0.4
# Bahnhofsviertel               0.2
# Westend-Süd                   0.2
# Westend-Nord                  0.2
#
# [5 rows x 28 columns]

# %%
df = data.drop(['Bahnhofsviertel','Berkersheim']) # rm missing values
X = df[list(df)[0:5:]]

display(X.head())
Y = df[list(df)[10::]] # CDUbis V-Partei³
display(Y.head())
# Out:
#               Anteil Bruttoarbeitsentgelt bis 2.000  \
# Stadtteil
# Altstadt                                   0.237559
# Innenstadt                                 0.292273
# Westend-Süd                                0.085496
# Westend-Nord                               0.153124
# Nordend-West                               0.121130
#
#               Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000  \
# Stadtteil
# Altstadt                                              0.398122
# Innenstadt                                            0.387458
# Westend-Süd                                           0.238550
# Westend-Nord                                          0.309922
# Nordend-West                                          0.349552
#
#               Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000  \
# Stadtteil
# Altstadt                                              0.141784
# Innenstadt                                            0.106383
# Westend-Süd                                           0.139122
# Westend-Nord                                          0.149040
# Nordend-West                                          0.158217
#
#               Anteil Bruttoarbeitsentgelt über 5.000  \
# Stadtteil
# Altstadt                                    0.222535
# Innenstadt                                  0.213886
# Westend-Süd                                 0.536832
# Westend-Nord                                0.387913
# Nordend-West                                0.371101
#
#               Median Bruttoarbeitsentgelte
# Stadtteil
# Altstadt                            3270.0
# Innenstadt                          2932.0
# Westend-Süd                         5247.0
# Westend-Nord                        4236.0
# Nordend-West                        4172.0
#               Anteil CDU  Anteil SPD  Anteil GRÜNE  Anteil DIE LINKE  \
# Stadtteil
# Altstadt            26.3        17.6          14.6              13.0
# Innenstadt          26.0        15.3          15.0              13.7
# Westend-Süd         31.6        11.9          13.6               6.7
# Westend-Nord        28.7        15.9          16.2               9.4
# Nordend-West        25.3        15.6          20.1              12.8
#
#               Anteil AfD  Anteil FDP  Anteil PIRATEN  Anteil NPD  \
# Stadtteil
# Altstadt             8.3        15.2             0.5         0.4
# Innenstadt           7.8        16.9             0.7         0.3
# Westend-Süd          6.2        27.9             0.1         0.0
# Westend-Nord         5.2        22.2             0.4         0.1
# Nordend-West         5.1        17.7             0.5         0.1
#
#               Anteil FREIE WÄHLER  Anteil Die PARTEI  Anteil BüSo  \
# Stadtteil
# Altstadt                      0.4                1.9          0.0
# Innenstadt                    0.2                2.0          0.0
# Westend-Süd                   0.1                0.6          0.0
# Westend-Nord                  0.1                0.7          0.0
# Nordend-West                  0.2                1.2          0.0
#
#               Anteil MLPD  Anteil BGE  Anteil DKP  Anteil DM  Anteil ÖDP  \
# Stadtteil
# Altstadt              0.0         0.3         0.0        0.2         0.3
# Innenstadt            0.1         0.1         0.0        0.4         0.2
# Westend-Süd           0.0         0.2         0.0        0.1         0.2
# Westend-Nord          0.0         0.1         0.1        0.2         0.1
# Nordend-West          0.0         0.3         0.1        0.1         0.2
#
#               Anteil Tierschutzpartei  Anteil V-Partei³
# Stadtteil
# Altstadt                          0.8               0.2
# Innenstadt                        0.7               0.4
# Westend-Süd                       0.4               0.2
# Westend-Nord                      0.4               0.2
# Nordend-West                      0.6               0.2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
xtrain, xtest, ytrain, ytest=train_test_split(X, Y, test_size=0.25)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
gbr = GradientBoostingRegressor()
model = MultiOutputRegressor(estimator=gbr)
model.fit(xtrain, ytrain)
score = model.score(xtrain, ytrain)
print("Training score:", score)
ypred = model.predict(xtest)
print(mean_squared_error(ytest, ypred))
# Out:
# Training score: 0.9993472699632657
# 3.568810493636107

# %%
df_ypred = pd.DataFrame(ypred,index=ytest.index,columns=list(ytest))
df_ypred.head()
# Out:
#               Anteil CDU  Anteil SPD  Anteil GRÜNE  Anteil DIE LINKE  \
# Stadtteil
# Sossenheim     22.993649   24.272427     11.322915         11.981213
# Nordend-West   25.896193   16.219867     20.402097          9.864588
# Sindlingen     25.615330   24.769543      8.557302         12.114163
# Fechenheim     24.953081   25.556047     10.209601         11.428792
# Heddernheim    25.439345   24.528367     12.012534         11.346054
#
#               Anteil AfD  Anteil FDP  Anteil PIRATEN  Anteil NPD  \
# Stadtteil
# Sossenheim     12.208696    9.430853        0.641564    0.226005
# Nordend-West    4.643555   19.344016        0.419033    0.058643
# Sindlingen     12.791473    9.812432        0.530412    0.279912
# Fechenheim     12.216640    9.513711        0.687818    0.696232
# Heddernheim    11.542612   10.594986        0.437289    0.309214
#
#               Anteil FREIE WÄHLER  Anteil Die PARTEI  Anteil BüSo  \
# Stadtteil
# Sossenheim               0.514601           1.505227     0.000051
# Nordend-West             0.181296           1.150012     0.000051
# Sindlingen               0.752893           1.202291     0.000051
# Fechenheim               0.894150           1.656388     0.000051
# Heddernheim              0.463206           1.059822     0.000051
#
#               Anteil MLPD  Anteil BGE  Anteil DKP  Anteil DM  Anteil ÖDP  \
# Stadtteil
# Sossenheim       0.157706    0.250263    0.097153   0.305321    0.248610
# Nordend-West     0.001187    0.262771    0.041004   0.097946    0.165355
# Sindlingen       0.100486    0.262841    0.097671   0.387631    0.101556
# Fechenheim       0.301102    0.297695    0.009068   0.296435    0.101831
# Heddernheim      0.006793    0.220549    0.004143   0.199655    0.162140
#
#               Anteil Tierschutzpartei  Anteil V-Partei³
# Stadtteil
# Sossenheim                   1.607486          0.120343
# Nordend-West                 0.416278          0.278974
# Sindlingen                   1.607113          0.167617
# Fechenheim                   1.170463          0.101247
# Heddernheim                  1.362155          0.178495

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(len(list(ytest)), sharex=True, sharey=False, figsize=(5,4*len(list(ytest))))

for i,stadtteil in enumerate(list(ytest)):
    print(stadtteil)
    df_stadtteil = pd.DataFrame(index=ytest.index)
    df_stadtteil['predicted'] = df_ypred[stadtteil]
    df_stadtteil['ground truth'] = ytest[stadtteil]
    df_stadtteil.plot.bar(title=stadtteil,ax=axes[i])
display(fig)
#fig.savefig('./output/predict_parties_test.png', format='png')
# Out:
# Anteil CDU
# Anteil SPD
# Anteil GRÜNE
# Anteil DIE LINKE
# Anteil AfD
# Anteil FDP
# Anteil PIRATEN
# Anteil NPD
# Anteil FREIE WÄHLER
# Anteil Die PARTEI
# Anteil BüSo
# Anteil MLPD
# Anteil BGE
# Anteil DKP
# Anteil DM
# Anteil ÖDP
# Anteil Tierschutzpartei
# Anteil V-Partei³

# %%
# %%capture
! pip install seaborn

import seaborn as sns
# %matplotlib inline

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title, p):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel(p)
    plt.ylabel('Proportion')

    plt.show()
    plt.close()

parties=["Anteil CDU","Anteil SPD","Anteil GRÜNE","Anteil DIE LINKE","Anteil AfD","Anteil FDP"]
j=0
ypred_train = model.predict(xtrain)
for party in parties:
    pred=[]
    for i in range(0,len(ypred)):
        pred.append(ypred[i][j])
    Title = 'Distribution  Plot of  Predicted Value Using Test Data vs Test Data Distribution'
    DistributionPlot(ytest[party], pred, "Actual Values (Test)", "Predicted Values (Test)", Title, party)
    j+=1

# %%
# all the features used are strongly correlatated 

X.corr()
# Out:
#                                                   Anteil Bruttoarbeitsentgelt bis 2.000  \
# Anteil Bruttoarbeitsentgelt bis 2.000                                          1.000000
# Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000                               0.728223
# Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000                              -0.875856
# Anteil Bruttoarbeitsentgelt über 5.000                                        -0.890893
# Median Bruttoarbeitsentgelte                                                  -0.920591
#
#                                                   Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000  \
# Anteil Bruttoarbeitsentgelt bis 2.000                                                     0.728223
# Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000                                          1.000000
# Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000                                         -0.573799
# Anteil Bruttoarbeitsentgelt über 5.000                                                   -0.952654
# Median Bruttoarbeitsentgelte                                                             -0.909455
#
#                                                   Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000  \
# Anteil Bruttoarbeitsentgelt bis 2.000                                                    -0.875856
# Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000                                         -0.573799
# Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000                                          1.000000
# Anteil Bruttoarbeitsentgelt über 5.000                                                    0.692246
# Median Bruttoarbeitsentgelte                                                              0.748995
#
#                                                   Anteil Bruttoarbeitsentgelt über 5.000  \
# Anteil Bruttoarbeitsentgelt bis 2.000                                          -0.890893
# Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000                               -0.952654
# Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000                                0.692246
# Anteil Bruttoarbeitsentgelt über 5.000                                          1.000000
# Median Bruttoarbeitsentgelte                                                    0.979961
#
#                                                   Median Bruttoarbeitsentgelte
# Anteil Bruttoarbeitsentgelt bis 2.000                                -0.920591
# Anteil Bruttoarbeitsentgelt über 2.000 bis 4.000                     -0.909455
# Anteil Bruttoarbeitsentgelt über 4.000 bis 5.000                      0.748995
# Anteil Bruttoarbeitsentgelt über 5.000                                0.979961
# Median Bruttoarbeitsentgelte                                          1.000000

# %%
# I used some other data


import numpy as np
final_merge_2011=pd.read_csv(r"D:/Uni/SS20/DataScience1/Project/DataScienceProject/regression/finalmergeother.csv")
final_merge_2011.drop(2,inplace=True)
final_merge_2011.drop(3,inplace=True)
final_merge_2011.drop(31,inplace=True)
final_merge_2011
# Out:
#     Unnamed: 0  Codes  \
# 0            0      1
# 1            1      2
# 4            4     10
# 5            5     10
# 6            6      4
# 7            7      5
# 8            8      6
# 9            9      7
# 10          10      8
# 11          11      9
# 12          12     11
# 13          13     12
# 14          14     13
# 15          15     14
# 16          16     16
# 17          17     17
# 18          18     18
# 19          19     19
# 20          20     20
# 21          21     21
# 22          22     22
# 23          23     24
# 24          24     25
# 25          25     26
# 26          26     27
# 27          27     28
# 28          28     29
# 29          29     30
# 30          30     31
# 32          32     33
# 33          33     34
# 34          34     35
# 35          35     36
# 36          36     37
# 37          37     38
# 38          38     39
# 39          39     40
# 40          40     41
# 41          41     42
# 42          42     43
# 43          43     44
# 44          44     45
# 45          45     46
# 46          46     47
#
#     Sozialversicherungspflichtig Beschäftigte (Wohnort) Bruttoarbeitsentgelt bis 2.000   2010  \
# 0                                               253.0
# 1                                               522.0
# 4                                               594.0
# 5                                               594.0
# 6                                               448.0
# 7                                               375.0
# 8                                              1068.0
# 9                                              1154.0
# 10                                             1438.0
# 11                                             1369.0
# 12                                             2202.0
# 13                                             1361.0
# 14                                             1302.0
# 15                                             1024.0
# 16                                              752.0
# 17                                             1313.0
# 18                                             1065.0
# 19                                             1819.0
# 20                                              957.0
# 21                                              374.0
# 22                                              846.0
# 23                                              990.0
# 24                                              767.0
# 25                                              849.0
# 26                                              788.0
# 27                                              686.0
# 28                                              877.0
# 29                                              702.0
# 30                                              367.0
# 32                                              356.0
# 33                                              526.0
# 34                                             1140.0
# 35                                              985.0
# 36                                             1128.0
# 37                                              601.0
# 38                                              662.0
# 39                                              860.0
# 40                                             1034.0
# 41                                              191.0
# 42                                              377.0
# 43                                              196.0
# 44                                              670.0
# 45                                              845.0
# 46                                              513.0
#
#     Sozialversicherungspflichtig Beschäftigte (Wohnort) Bruttoarbeitsentgelt über 2.000 bis 4.000   2010  \
# 0                                               424.0
# 1                                               692.0
# 4                                               897.0
# 5                                               897.0
# 6                                              1250.0
# 7                                               759.0
# 8                                              3082.0
# 9                                              3247.0
# 10                                             3299.0
# 11                                             3689.0
# 12                                             3149.0
# 13                                             3444.0
# 14                                             3223.0
# 15                                             2567.0
# 16                                             1542.0
# 17                                             3098.0
# 18                                             2310.0
# 19                                             2626.0
# 20                                             2001.0
# 21                                              629.0
# 22                                             1708.0
# 23                                             1954.0
# 24                                             1521.0
# 25                                             1729.0
# 26                                             1808.0
# 27                                             1658.0
# 28                                             1700.0
# 29                                             1433.0
# 30                                              710.0
# 32                                              593.0
# 33                                             1041.0
# 34                                             1575.0
# 35                                             1694.0
# 36                                             2099.0
# 37                                             1058.0
# 38                                             1297.0
# 39                                             1749.0
# 40                                             1805.0
# 41                                              424.0
# 42                                              905.0
# 43                                              535.0
# 44                                             1229.0
# 45                                             1930.0
# 46                                             1128.0
#
#     Sozialversicherungspflichtig Beschäftigte (Wohnort) Bruttoarbeitsentgelt über 4.000 bis 5.000   2010  \
# 0                                               151.0
# 1                                               190.0
# 4                                               279.0
# 5                                               279.0
# 6                                               729.0
# 7                                               365.0
# 8                                              1395.0
# 9                                              1380.0
# 10                                             1173.0
# 11                                             1179.0
# 12                                              672.0
# 13                                             1321.0
# 14                                             1313.0
# 15                                             1027.0
# 16                                              392.0
# 17                                              768.0
# 18                                              621.0
# 19                                              440.0
# 20                                              568.0
# 21                                              179.0
# 22                                              438.0
# 23                                              509.0
# 24                                              367.0
# 25                                              534.0
# 26                                              663.0
# 27                                              526.0
# 28                                              374.0
# 29                                              401.0
# 30                                              157.0
# 32                                              113.0
# 33                                              253.0
# 34                                              264.0
# 35                                              365.0
# 36                                              502.0
# 37                                              271.0
# 38                                              423.0
# 39                                              470.0
# 40                                              381.0
# 41                                              149.0
# 42                                              410.0
# 43                                              167.0
# 44                                              321.0
# 45                                              611.0
# 46                                              337.0
#
#     Sozialversicherungspflichtig Beschäftigte (Wohnort) Bruttoarbeitsentgelt über 5.000   2010  \
# 0                                               237.0
# 1                                               382.0
# 4                                               610.0
# 5                                               610.0
# 6                                              2813.0
# 7                                               950.0
# 8                                              3272.0
# 9                                              2662.0
# 10                                             1951.0
# 11                                             1652.0
# 12                                              768.0
# 13                                             2503.0
# 14                                             3197.0
# 15                                             2316.0
# 16                                              534.0
# 17                                             1105.0
# 18                                              730.0
# 19                                              452.0
# 20                                              884.0
# 21                                              283.0
# 22                                              618.0
# 23                                              708.0
# 24                                              513.0
# 25                                              672.0
# 26                                             1165.0
# 27                                              919.0
# 28                                              500.0
# 29                                              697.0
# 30                                              191.0
# 32                                               67.0
# 33                                              401.0
# 34                                              270.0
# 35                                              465.0
# 36                                              558.0
# 37                                              193.0
# 38                                              393.0
# 39                                              546.0
# 40                                              397.0
# 41                                              350.0
# 42                                              900.0
# 43                                              284.0
# 44                                              529.0
# 45                                             1077.0
# 46                                              460.0
#
#     Sozialversicherungspflichtig Beschäftigte (Wohnort) Median Bruttoarbeitsentgelte  2010  \
# 0                                              3270.0
# 1                                              2932.0
# 4                                              3190.0
# 5                                              3190.0
# 6                                              5247.0
# 7                                              4236.0
# 8                                              4172.0
# 9                                              3891.0
# 10                                             3464.0
# 11                                             3341.0
# 12                                             2620.0
# 13                                             3720.0
# 14                                             3996.0
# 15                                             3896.0
# 16                                             2983.0
# 17                                             3083.0
# 18                                             3079.0
# 19                                             2466.0
# 20                                             3162.0
# 21                                             3099.0
# 22                                             3019.0
# 23                                             3032.0
# 24                                             2995.0
# 25                                             3139.0
# 26                                             3582.0
# 27                                             3426.0
# 28                                             2868.0
# 29                                             3208.0
# 30                                             2849.0
# 32                                             2546.0
# 33                                             2984.0
# 34                                             2453.0
# 35                                             2736.0
# 36                                             2920.0
# 37                                             2806.0
# 38                                             3073.0
# 39                                             2951.0
# 40                                             2732.0
# 41                                             3758.0
# 42                                             4027.0
# 43                                             3355.0
# 44                                             3037.0
# 45                                             3347.0
# 46                                             3106.0
#
#     Stadtteilnummer  Anteil Wahlberechtigte ohne Sperrvermerk  Anteil Wähler  \
# 0                 1                                      73.2           74.8
# 1                 2                                      71.6           67.6
# 4                10                                      73.0           74.1
# 5                10                                      73.0           74.1
# 6                 4                                      62.8           84.8
# 7                 5                                      69.3           78.6
# 8                 6                                      67.3           85.0
# 9                 7                                      70.2           82.8
# 10                8                                      72.1           77.9
# 11                9                                      74.5           78.1
# 12               11                                      75.3           68.9
# 13               12                                      72.3           77.2
# 14               13                                      68.8           81.2
# 15               14                                      68.2           78.8
# 16               16                                      78.5           71.6
# 17               17                                      76.4           70.8
# 18               18                                      82.1           69.6
# 19               19                                      85.1           61.3
# 20               20                                      78.8           73.2
# 21               21                                      78.3           79.4
# 22               22                                      79.6           73.1
# 23               24                                      80.4           72.3
# 24               25                                      81.7           69.6
# 25               26                                      79.2           72.4
# 26               27                                      73.9           80.1
# 27               28                                      74.2           78.2
# 28               29                                      80.9           70.2
# 29               30                                      80.6           75.1
# 30               31                                      82.5           67.0
# 32               33                                      85.0           67.8
# 33               34                                      77.8           75.3
# 34               35                                      83.3           61.2
# 35               36                                      82.3           66.5
# 36               37                                      83.2           68.7
# 37               38                                      85.6           66.6
# 38               39                                      84.7           67.2
# 39               40                                      84.9           69.3
# 40               41                                      84.4           63.3
# 41               42                                      75.0           84.7
# 42               43                                      78.3           82.4
# 43               44                                      76.5           84.1
# 44               45                                      81.7           71.4
# 45               46                                      75.9           78.9
# 46               47                                      81.0           73.1
#
#     ...  Arbeitslose Arbeitslosendichte Männer in %  \
# 0   ...                                         4,6
# 1   ...                                        10,2
# 4   ...                                          10
# 5   ...                                         7,2
# 6   ...                                         2,4
# 7   ...                                         3,7
# 8   ...                                           3
# 9   ...                                         4,4
# 10  ...                                         5,5
# 11  ...                                           5
# 12  ...                                         7,6
# 13  ...                                         4,5
# 14  ...                                         3,5
# 15  ...                                         3,2
# 16  ...                                         6,1
# 17  ...                                           5
# 18  ...                                         5,3
# 19  ...                                           6
# 20  ...                                         7,1
# 21  ...                                         5,6
# 22  ...                                         4,9
# 23  ...                                         5,8
# 24  ...                                         6,5
# 25  ...                                         4,5
# 26  ...                                         3,9
# 27  ...                                         4,3
# 28  ...                                         6,2
# 29  ...                                         5,7
# 30  ...                                         5,6
# 32  ...                                          12
# 33  ...                                           6
# 34  ...                                        11,3
# 35  ...                                           9
# 36  ...                                         7,9
# 37  ...                                         7,1
# 38  ...                                           9
# 39  ...                                         7,1
# 40  ...                                         8,2
# 41  ...                                           2
# 42  ...                                         2,1
# 43  ...                                         2,2
# 44  ...                                         5,6
# 45  ...                                         3,8
# 46  ...                                         5,1
#
#     Arbeitslose unter 25-Jährige  \
# 0                              5
# 1                             29
# 4                             17
# 5                             16
# 6                              8
# 7                             18
# 8                             23
# 9                             39
# 10                            59
# 11                            50
# 12                           103
# 13                            63
# 14                            47
# 15                            46
# 16                            30
# 17                            66
# 18                            48
# 19                            74
# 20                            55
# 21                            22
# 22                            42
# 23                            56
# 24                            43
# 25                            47
# 26                            31
# 27                            43
# 28                            50
# 29                            40
# 30                            10
# 32                            13
# 33                            21
# 34                            76
# 35                            68
# 36                            63
# 37                            47
# 38                            57
# 39                            64
# 40                            80
# 41                             3
# 42                            14
# 43                             7
# 44                            35
# 45                            22
# 46                            20
#
#     Arbeitslose Arbeitslosendichte unter 25-Jährige in %  \
# 0                                                 1,7
# 1                                                 4,3
# 4                                                 5,2
# 5                                                 2,6
# 6                                                 0,6
# 7                                                   2
# 8                                                 1,1
# 9                                                 2,2
# 10                                                2,7
# 11                                                2,6
# 12                                                3,4
# 13                                                1,7
# 14                                                  2
# 15                                                2,3
# 16                                                2,6
# 17                                                2,8
# 18                                                2,2
# 19                                                2,7
# 20                                                3,4
# 21                                                2,5
# 22                                                2,6
# 23                                                  3
# 24                                                2,9
# 25                                                2,2
# 26                                                1,9
# 27                                                  3
# 28                                                3,1
# 29                                                2,9
# 30                                                1,5
# 32                                                2,9
# 33                                                2,3
# 34                                                3,9
# 35                                                3,8
# 36                                                3,1
# 37                                                4,5
# 38                                                4,3
# 39                                                3,8
# 40                                                4,4
# 41                                                0,7
# 42                                                1,6
# 43                                                1,8
# 44                                                2,7
# 45                                                1,4
# 46                                                2,2
#
#     Arbeitslose Deutsche  Arbeitslose Arbeitslosendichte Deutsche in %  \
# 0                     81                                             5
# 1                    212                                           8,3
# 4                     95                                           8,5
# 5                    149                                           5,6
# 6                    170                                           1,9
# 7                    126                                           2,8
# 8                    406                                           2,5
# 9                    487                                           3,3
# 10                   542                                           4,1
# 11                   567                                           4,1
# 12                   766                                           6,9
# 13                   602                                           3,3
# 14                   443                                           2,8
# 15                   352                                           2,8
# 16                   271                                           4,6
# 17                   427                                           4,1
# 18                   408                                           4,3
# 19                   490                                           5,4
# 20                   429                                           5,4
# 21                   135                                           4,5
# 22                   310                                           4,2
# 23                   360                                           4,4
# 24                   336                                           5,1
# 25                   305                                           3,8
# 26                   261                                             3
# 27                   239                                           3,2
# 28                   326                                             5
# 29                   252                                           4,1
# 30                   150                                           4,9
# 32                   200                                           8,8
# 33                   207                                           4,6
# 34                   587                                           9,8
# 35                   430                                           7,4
# 36                   480                                           6,2
# 37                   247                                           6,2
# 38                   350                                           6,4
# 39                   388                                           5,8
# 40                   484                                           7,2
# 41                    33                                           1,3
# 42                   101                                           1,8
# 43                    48                                             2
# 44                   264                                           4,5
# 45                   285                                             3
# 46                   155                                           4,1
#
#     Arbeitslose Ausländerinnen und Ausländer  \
# 0                                         64
# 1                                        190
# 4                                         81
# 5                                        144
# 6                                         76
# 7                                         94
# 8                                        159
# 9                                        252
# 10                                       398
# 11                                       290
# 12                                       690
# 13                                       435
# 14                                       294
# 15                                       169
# 16                                       210
# 17                                       288
# 18                                       245
# 19                                       492
# 20                                       299
# 21                                        89
# 22                                       137
# 23                                       215
# 24                                       198
# 25                                       191
# 26                                       150
# 27                                       117
# 28                                       234
# 29                                       209
# 30                                        69
# 32                                       131
# 33                                       143
# 34                                       530
# 35                                       360
# 36                                       402
# 37                                       179
# 38                                       232
# 39                                       225
# 40                                       317
# 41                                        14
# 42                                        53
# 43                                        15
# 44                                       140
# 45                                       106
# 46                                        97
#
#     Arbeitslose Arbeitslosendichte Ausländerinnen und Ausländer in %  \
# 0                                                 6,3
# 1                                                 8,3
# 4                                                 6,8
# 5                                                 7,8
# 6                                                 2,4
# 7                                                   5
# 8                                                 3,5
# 9                                                 5,7
# 10                                                6,6
# 11                                                6,1
# 12                                                7,2
# 13                                                5,3
# 14                                                5,1
# 15                                                3,9
# 16                                                7,8
# 17                                                5,4
# 18                                                7,4
# 19                                                6,7
# 20                                                7,9
# 21                                                  5
# 22                                                5,1
# 23                                                7,7
# 24                                                7,1
# 25                                                6,6
# 26                                                5,3
# 27                                                5,5
# 28                                                7,6
# 29                                                7,3
# 30                                                6,7
# 32                                               14,4
# 33                                                8,4
# 34                                               11,5
# 35                                                8,5
# 36                                                8,7
# 37                                                9,3
# 38                                               10,1
# 39                                                7,5
# 40                                                  9
# 41                                                3,6
# 42                                                3,8
# 43                                                3,8
# 44                                                8,7
# 45                                                4,7
# 46                                                6,6
#
#     Arbeitslose 55- bis unter 65-Jährige  \
# 0                                     29
# 1                                     57
# 4                                     23
# 5                                     45
# 6                                     42
# 7                                     38
# 8                                    110
# 9                                    136
# 10                                   165
# 11                                   149
# 12                                   224
# 13                                   164
# 14                                   123
# 15                                   106
# 16                                    57
# 17                                   116
# 18                                   105
# 19                                   160
# 20                                   107
# 21                                    35
# 22                                    76
# 23                                    98
# 24                                    91
# 25                                    70
# 26                                    73
# 27                                    67
# 28                                    77
# 29                                    71
# 30                                    34
# 32                                    52
# 33                                    53
# 34                                   137
# 35                                   115
# 36                                   148
# 37                                    61
# 38                                    95
# 39                                   130
# 40                                   139
# 41                                     8
# 42                                    29
# 43                                    17
# 44                                    79
# 45                                    79
# 46                                    39
#
#     Arbeitslose Arbeitslosendichte 55- bis unter 65-Jährige in %  \
# 0                                                 6,8
# 1                                                 8,9
# 4                                                 9,1
# 5                                                 8,2
# 6                                                 2,6
# 7                                                 4,2
# 8                                                 3,6
# 9                                                 4,8
# 10                                                5,8
# 11                                                  5
# 12                                                8,1
# 13                                                4,9
# 14                                                4,1
# 15                                                3,5
# 16                                                3,7
# 17                                                4,5
# 18                                                4,3
# 19                                                6,3
# 20                                                5,5
# 21                                                4,5
# 22                                                3,9
# 23                                                5,3
# 24                                                5,7
# 25                                                4,2
# 26                                                3,6
# 27                                                4,2
# 28                                                4,7
# 29                                                5,3
# 30                                                4,3
# 32                                                9,1
# 33                                                4,5
# 34                                                8,2
# 35                                                8,7
# 36                                                7,1
# 37                                                6,2
# 38                                                6,9
# 39                                                8,3
# 40                                                7,9
# 41                                                1,4
# 42                                                3,3
# 43                                                3,3
# 44                                                5,7
# 45                                                3,5
# 46                                                4,5
#
#     SGB III Leistungsempfänger/innen Insgesamt
# 0                                           49
# 1                                           79
# 4                                           26
# 5                                           56
# 6                                          119
# 7                                           78
# 8                                          216
# 9                                          233
# 10                                         276
# 11                                         227
# 12                                         324
# 13                                         330
# 14                                         214
# 15                                         197
# 16                                         126
# 17                                         198
# 18                                         153
# 19                                         246
# 20                                         141
# 21                                          51
# 22                                         126
# 23                                         145
# 24                                         137
# 25                                         127
# 26                                         110
# 27                                         110
# 28                                         121
# 29                                         112
# 30                                          56
# 32                                          71
# 33                                          86
# 34                                         174
# 35                                         183
# 36                                         179
# 37                                         107
# 38                                         135
# 39                                         163
# 40                                         150
# 41                                          19
# 42                                          64
# 43                                          28
# 44                                         108
# 45                                         122
# 46                                          49
#
# [44 rows x 79 columns]

# %%
# I normalized the data, except the target values.

tempvalue = final_merge_2011[['Sozialversicherungspflichtig Beschäftigte (Wohnort) Median Bruttoarbeitsentgelte  2010','Arbeitslose Arbeitslosendichte in %','Sozialversicherungspflichtig Beschäftigte (Wohnort) Nebenjobdichte in %',"Anteil CDU","Anteil SPD","Anteil GRÜNE","Anteil DIE LINKE","Anteil AfD","Anteil FDP"]].copy()
workvalue=pd.DataFrame(index=tempvalue.index)

workvalue['Median Bruttoarbeitsentgelte']=tempvalue['Sozialversicherungspflichtig Beschäftigte (Wohnort) Median Bruttoarbeitsentgelte  2010'].astype(float)
workvalue['Arbeitslosendichte']=tempvalue['Arbeitslose Arbeitslosendichte in %'].str.replace(',', '.').astype(float)
workvalue['Nebenjobdichte']=tempvalue['Sozialversicherungspflichtig Beschäftigte (Wohnort) Nebenjobdichte in %'].str.replace(',', '.').astype(float)
workvalue[["Anteil CDU","Anteil SPD","Anteil GRÜNE","Anteil DIE LINKE","Anteil AfD","Anteil FDP"]]=tempvalue[["Anteil CDU","Anteil SPD","Anteil GRÜNE","Anteil DIE LINKE","Anteil AfD","Anteil FDP"]]
workvalue['Median Bruttoarbeitsentgelte']=workvalue['Median Bruttoarbeitsentgelte']/max(workvalue['Median Bruttoarbeitsentgelte'])
workvalue['Arbeitslosendichte']=workvalue['Arbeitslosendichte']/max(workvalue['Arbeitslosendichte'])
workvalue['Nebenjobdichte']=workvalue['Nebenjobdichte']/max(workvalue['Nebenjobdichte'])
workvalue
# Out:
#     Median Bruttoarbeitsentgelte  Arbeitslosendichte  Nebenjobdichte  \
# 0                       0.623213            0.518868        0.687500
# 1                       0.558796            0.783019        0.796875
# 4                       0.607966            0.726415        0.765625
# 5                       0.607966            0.613208        0.843750
# 6                       1.000000            0.188679        0.375000
# 7                       0.807318            0.320755        0.625000
# 8                       0.795121            0.254717        0.578125
# 9                       0.741567            0.358491        0.609375
# 10                      0.660187            0.462264        0.796875
# 11                      0.636745            0.433962        0.750000
# 12                      0.499333            0.660377        0.984375
# 13                      0.708977            0.367925        0.718750
# 14                      0.761578            0.320755        0.687500
# 15                      0.742520            0.292453        0.609375
# 16                      0.568515            0.528302        0.937500
# 17                      0.587574            0.433962        0.953125
# 18                      0.586812            0.481132        0.843750
# 19                      0.469983            0.566038        0.937500
# 20                      0.602630            0.584906        0.812500
# 21                      0.590623            0.443396        0.859375
# 22                      0.575376            0.424528        0.953125
# 23                      0.577854            0.490566        0.906250
# 24                      0.570802            0.537736        0.875000
# 25                      0.598247            0.433962        0.843750
# 26                      0.682676            0.339623        0.734375
# 27                      0.652945            0.349057        0.781250
# 28                      0.546598            0.547170        0.968750
# 29                      0.611397            0.481132        1.000000
# 30                      0.542977            0.509434        0.921875
# 32                      0.485230            0.981132        0.890625
# 33                      0.568706            0.528302        0.859375
# 34                      0.467505            1.000000        0.968750
# 35                      0.521441            0.735849        0.968750
# 36                      0.556508            0.679245        0.921875
# 37                      0.534782            0.679245        0.953125
# 38                      0.585668            0.707547        0.937500
# 39                      0.562417            0.603774        0.984375
# 40                      0.520678            0.735849        1.000000
# 41                      0.716219            0.150943        0.625000
# 42                      0.767486            0.207547        0.640625
# 43                      0.639413            0.216981        0.765625
# 44                      0.578807            0.509434        0.890625
# 45                      0.637888            0.320755        0.812500
# 46                      0.591957            0.452830        0.937500
#
#     Anteil CDU  Anteil SPD  Anteil GRÜNE  Anteil DIE LINKE  Anteil AfD  \
# 0         26.3        17.6          14.6              13.0         8.3
# 1         26.0        15.3          15.0              13.7         7.8
# 4         21.4        15.6          18.4              16.5         7.1
# 5         21.4        15.6          18.4              16.5         7.1
# 6         31.6        11.9          13.6               6.7         6.2
# 7         28.7        15.9          16.2               9.4         5.2
# 8         25.3        15.6          20.1              12.8         5.1
# 9         20.7        17.6          23.6              16.6         4.5
# 10        23.7        19.4          18.7              14.2         6.3
# 11        22.2        21.4          18.3              16.1         6.8
# 12        24.4        18.1          13.4              12.7         9.5
# 13        22.5        19.0          19.1              14.1         6.0
# 14        27.1        15.9          18.6              10.3         5.8
# 15        30.2        17.4          13.6               9.1         7.6
# 16        27.4        22.5          11.5              11.2        10.5
# 17        26.1        22.4          11.9              10.9        10.3
# 18        30.6        23.2           9.5               8.7        12.4
# 19        25.3        25.6           9.6              11.3        12.2
# 20        23.6        21.2          13.9              16.2         9.1
# 21        27.5        23.0          13.4              12.6         7.7
# 22        24.5        24.3          12.8              12.6        11.1
# 23        24.7        24.7          13.3              13.0        10.1
# 24        26.2        24.2          12.6              10.8        10.9
# 25        23.9        22.6          14.0              14.1         8.4
# 26        27.3        19.2          15.2              11.8         7.5
# 27        27.6        19.4          15.7              11.5         7.5
# 28        24.4        24.1          12.3              14.3         9.2
# 29        26.1        21.8          14.2              11.9         8.7
# 30        25.7        23.2          12.2              11.7        12.8
# 32        17.5        29.6           9.7              18.8        13.1
# 33        28.3        21.6          14.5              11.1         8.7
# 34        24.8        25.6          10.5              12.6        11.6
# 35        21.7        23.7          13.7              14.6        11.1
# 36        26.7        24.5           8.8              10.5        14.2
# 37        29.3        25.9           8.1               9.0        13.6
# 38        31.1        24.3           7.8               8.2        14.5
# 39        28.6        24.1          10.1              10.2        11.6
# 40        30.2        22.7           8.1               9.7        13.6
# 41        36.1        17.0          12.9               7.5         9.0
# 42        33.6        16.9          12.8               7.2         7.4
# 43        33.9        19.0          11.8               7.4        10.2
# 44        30.2        21.1          11.1               9.4        12.8
# 45        30.4        20.0          11.7               8.5        10.0
# 46        28.8        22.0          11.9              10.8        11.2
#
#     Anteil FDP
# 0         15.2
# 1         16.9
# 4         16.8
# 5         16.8
# 6         27.9
# 7         22.2
# 8         17.7
# 9         13.1
# 10        13.6
# 11        10.9
# 12        17.3
# 13        15.1
# 14        19.2
# 15        18.9
# 16        12.2
# 17        13.6
# 18        11.1
# 19         9.6
# 20        10.7
# 21        12.6
# 22        10.5
# 23         9.8
# 24        11.2
# 25        12.3
# 26        15.6
# 27        14.3
# 28        10.1
# 29        12.7
# 30         9.4
# 32         5.5
# 33        11.7
# 34         9.0
# 35         9.1
# 36        10.2
# 37         8.2
# 38         8.9
# 39        10.4
# 40        10.1
# 41        14.3
# 42        18.3
# 43        13.1
# 44        10.5
# 45        15.1
# 46        10.7

# %%
# Had a look at the correlation for all parties, example for the FDP



feature_names=['Median Bruttoarbeitsentgelte','Arbeitslosendichte','Nebenjobdichte']
party='Anteil FDP'
sns.regplot(x=feature_names[0], y=party, data=workvalue)
plt.ylim(0,)
# Out:
# (0.0, 30.225880277703595)

# %%
sns.regplot(x=feature_names[1], y=party, data=workvalue)
plt.ylim(0,)
# Out:
# (0.0, 29.164048466787907)

# %%
sns.regplot(x=feature_names[2], y=party, data=workvalue)
plt.ylim(0,)
# Out:
# (0.0, 29.02)

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(workvalue['Median Bruttoarbeitsentgelte'], workvalue[party])
print("The Pearson Correlation Coefficient for Median Bruttoarbeitsentgelte is", pearson_coef, " with a P-value of P =", p_value) 
pearson_coef, p_value = stats.pearsonr(workvalue['Arbeitslosendichte'], workvalue[party])
print("The Pearson Correlation Coefficient is for Arbeitslosendichte", pearson_coef, " with a P-value of P =", p_value)
pearson_coef, p_value = stats.pearsonr(workvalue['Nebenjobdichte'], workvalue[party])
print("The Pearson Correlation Coefficient is Nebenjobdichte", pearson_coef, " with a P-value of P =", p_value)
# ANOVA
f_val01, p_val01 = stats.f_oneway(workvalue['Median Bruttoarbeitsentgelte'], workvalue[party]) 
print( "ANOVA results for Median Bruttoarbeitsentgelte: F=", f_val01, ", P =", p_val01)
f_val02, p_val02 = stats.f_oneway(workvalue['Arbeitslosendichte'], workvalue[party]) 
print( "ANOVA results for Arbeitslosendichte: F=", f_val02, ", P =", p_val02)
f_val03, p_val03 = stats.f_oneway(workvalue['Nebenjobdichte'], workvalue[party]) 
print( "ANOVA results for Nebenjobdichte: F=", f_val03, ", P =", p_val03)
# Out:
# The Pearson Correlation Coefficient for Median Bruttoarbeitsentgelte is 0.8269949569554109  with a P-value of P = 4.5866216756069885e-12
# The Pearson Correlation Coefficient is for Arbeitslosendichte -0.5764936533904198  with a P-value of P = 4.212135834496876e-05
# The Pearson Correlation Coefficient is Nebenjobdichte -0.7773599045089586  with a P-value of P = 5.442681184389606e-10
# ANOVA results for Median Bruttoarbeitsentgelte: F= 403.68309740323957 , P = 3.1003014239320024e-34
# ANOVA results for Arbeitslosendichte: F= 410.7830881626746 , P = 1.6670134058393145e-34
# ANOVA results for Nebenjobdichte: F= 390.4006380753411 , P = 1.0143823963391906e-33

# %%
# lets try a Multivariate Linear Regression
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures


features=workvalue[list(workvalue)[0:3:]]
targets=workvalue[list(workvalue)[3::]]
f_train, f_test, t_train, t_test = train_test_split(features, targets, test_size=0.25, random_state=1)
Input=[('polynomial', PolynomialFeatures(degree=1,include_bias=True)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(f_train,t_train)
score = pipe.score(f_train, t_train)

t_pred = pipe.predict(f_test)

allresults = np.full((7, 7), 0)

for n in range(0,6):
    Input=[('polynomial', PolynomialFeatures(degree=n,include_bias=True)), ('model',LinearRegression())]
    pipe=Pipeline(Input)
    pipe.fit(f_train,t_train)
    score = pipe.score(f_train, t_train)
    print("Polynom: ",n," Training score:", score)
    t_pred = pipe.predict(f_test)
   # mse=mean_squared_error(tt, t_pred[:,j])
   # print("MSE for is : ",mse)
    j=0
    for pa in parties:
        tt=list(t_test[pa])
        mse=mean_squared_error(tt, t_pred[:,j])
        print("MSE for ",pa," is : ",mse)
        allresults[n][j]=mse
        j+=1
# Out:
# Polynom:  0  Training score: 1.2086012667119917e-17
# MSE for  Anteil CDU  is :  9.714912764003678
# MSE for  Anteil SPD  is :  13.866363636363628
# MSE for  Anteil GRÜNE  is :  13.82157943067034
# MSE for  Anteil DIE LINKE  is :  7.019100091827365
# MSE for  Anteil AfD  is :  10.203719008264459
# MSE for  Anteil FDP  is :  12.259100091827365
# Polynom:  1  Training score: 0.517553716279184
# MSE for  Anteil CDU  is :  11.27989435572717
# MSE for  Anteil SPD  is :  7.804521441847515
# MSE for  Anteil GRÜNE  is :  9.461945743295926
# MSE for  Anteil DIE LINKE  is :  7.3064815934541025
# MSE for  Anteil AfD  is :  6.249350200276126
# MSE for  Anteil FDP  is :  5.354581656007286
# Polynom:  2  Training score: 0.6692930675728753
# MSE for  Anteil CDU  is :  8.268684883469493
# MSE for  Anteil SPD  is :  7.564475854779406
# MSE for  Anteil GRÜNE  is :  8.725810282755862
# MSE for  Anteil DIE LINKE  is :  5.870317621173399
# MSE for  Anteil AfD  is :  6.2259725908509065
# MSE for  Anteil FDP  is :  7.00116164934579
# Polynom:  3  Training score: 0.8568032533979087
# MSE for  Anteil CDU  is :  46.27996707747884
# MSE for  Anteil SPD  is :  9.690436139572405
# MSE for  Anteil GRÜNE  is :  31.933353287708393
# MSE for  Anteil DIE LINKE  is :  23.692044810594595
# MSE for  Anteil AfD  is :  13.59408470641484
# MSE for  Anteil FDP  is :  4.975944983788076
# Polynom:  4  Training score: 1.0
# MSE for  Anteil CDU  is :  1619.0688444951309
# MSE for  Anteil SPD  is :  527.1222263577948
# MSE for  Anteil GRÜNE  is :  1396.3381285928642
# MSE for  Anteil DIE LINKE  is :  815.1865632080479
# MSE for  Anteil AfD  is :  133.209124549585
# MSE for  Anteil FDP  is :  784.4901271529277
# Polynom:  5  Training score: 1.0
# MSE for  Anteil CDU  is :  242.8153389871176
# MSE for  Anteil SPD  is :  993.0657922315299
# MSE for  Anteil GRÜNE  is :  1494.8864421958701
# MSE for  Anteil DIE LINKE  is :  371.70006785830367
# MSE for  Anteil AfD  is :  56.98101601749773
# MSE for  Anteil FDP  is :  143.38038982708912

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'model': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#  'model__copy_X': True,
#  'model__fit_intercept': True,
#  'model__n_jobs': 1,
#  'model__normalize': False,
#  'polynomial': PolynomialFeatures(degree=5, include_bias=True, interaction_only=False),
#  'polynomial__degree': 5,
#  'polynomial__include_bias': True,
#  'polynomial__interaction_only': False,
#  'steps': [('polynomial',
#    PolynomialFeatures(degree=5, include_bias=True, interaction_only=False)),
#   ('model',
#    LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))]}

# %%
#parties=["Anteil CDU","Anteil SPD","Anteil GRÜNE","Anteil DIE LINKE","Anteil AfD","Anteil FDP"]
Input=[('polynomial', PolynomialFeatures(degree=3,include_bias=True)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(f_train,t_train)
score = pipe.score(f_train, t_train)

t_pred = pipe.predict(f_test)
j=0
for party in parties:
    pred=[]
    for i in range(0,len(t_pred)):
        pred.append(t_pred[i][j])
    Title = 'Distribution  Plot of  Predicted Value Using Test Data vs Test Data Distribution'
    DistributionPlot(t_test[party], pred, "Actual Values (Test)", "Predicted Values (Test)", Title, party)
    j+=1

# %%
# let look how good one feature alone is
x_train, x_test, y_train, y_test = train_test_split(features, targets['Anteil SPD'], test_size=0.45, random_state=0)
pr = PolynomialFeatures(degree=3)
x_train_pr = pr.fit_transform(x_train[['Median Bruttoarbeitsentgelte']])
x_test_pr = pr.fit_transform(x_test[['Median Bruttoarbeitsentgelte']])
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
yhat = poly.predict(x_test_pr)

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([0, 50])
    plt.ylabel('Erreichte Prozent')
    plt.xlabel("Median Brutto")
    plt.legend()

# %%
PollyPlot(x_train[['Median Bruttoarbeitsentgelte']], x_test[['Median Bruttoarbeitsentgelte']], y_train, y_test, poly,pr)

# %%
#R2 of trainigndata
poly.score(x_train_pr, y_train)
# Out:
# 0.6041053685244527

# %%
#r2 of testdata
poly.score(x_test_pr, y_test)
# Out:
# 0.45722639894347605

# %%
Rsqu_test = []
lr = LinearRegression()
lr.fit(x_train[['Median Bruttoarbeitsentgelte']], y_train)
order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['Median Bruttoarbeitsentgelte']])
    
    x_test_pr = pr.fit_transform(x_test[['Median Bruttoarbeitsentgelte']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Out:
# Text(0.5, 1.0, 'R^2 Using Test Data')

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['Median Bruttoarbeitsentgelte','Arbeitslosendichte','Nebenjobdichte']])
x_test_pr=pr.fit_transform(x_test[['Median Bruttoarbeitsentgelte','Arbeitslosendichte','Nebenjobdichte']])
from sklearn.linear_model import Ridge

Rsqu_test = []
Rsqu_train = []
dummy1 = []
ALFA =  np.array(range(0,10))
for alfa in ALFA:
    RigeModel = Ridge(alpha=alfa) 
    RigeModel.fit(x_train_pr, y_train)
    Rsqu_test.append(RigeModel.score(x_test_pr, y_test))
    Rsqu_train.append(RigeModel.score(x_train_pr, y_train))
    
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(ALFA,Rsqu_test, label='validation data  ')
plt.plot(ALFA,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV
parameters1= [{'alpha': [0.001,0.01,0.1, 0.5, 0.7, 1.0, 1.5, 2, 3]}]
RR=Ridge()
Grid1 = GridSearchCV(RR, parameters1,cv=4)
Grid1.fit(features[['Median Bruttoarbeitsentgelte','Arbeitslosendichte','Nebenjobdichte']], targets[['Anteil SPD']])
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
BestRR.score(x_test[['Median Bruttoarbeitsentgelte','Arbeitslosendichte','Nebenjobdichte']], y_test)
# Out:
# 0.5862599681205081

# %%
#which proves sadly that a multivariante polynomial regression is not a good model for these data
